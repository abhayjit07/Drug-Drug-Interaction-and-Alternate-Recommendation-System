# %%
from datasets import load_dataset
import os
import json 
import re

# %%
# load all of pubmed -- note that this dataset is 360GB+, so I'm loading this in "streaming mode" -- https://huggingface.co/docs/datasets/stream
# https://huggingface.co/datasets/pubmed
# full_pubmed = load_dataset('pubmed', streaming=True, trust_remote_code=True)
full_pubmed = load_dataset('pubmed', streaming=False, trust_remote_code=True)
# make directory if it doesn't exist
if not os.path.isdir('pubmed_portions_1'):
    os.mkdir('pubmed_portions_1')

# download pubmed in portions
portion_size = 10 # 1 mil entries per portion
pubmed_portion = []
counter = 0

for idx, entry in enumerate(full_pubmed['train']): 
    try:
        # print(entry)
        pmid = entry['MedlineCitation']['PMID']
        year = entry['MedlineCitation']['DateCompleted']['Year']
        abstract_text = entry['MedlineCitation']['Article']['Abstract']['AbstractText']
        abstract_title = entry['MedlineCitation']['Article']['ArticleTitle']
        abstract_authors_list = entry['MedlineCitation']['Article']['AuthorList']['Author']['LastName']

        if len(abstract_text) > 20 and len(abstract_title) > 5 and len(abstract_authors_list) > 0 and year > 2015: # check that the abstract text, title, or authors are not empty
            pubmed_portion.append({'pmid':pmid, 'year':year, 'abstract_text':abstract_text, 'abstract_title':abstract_title, 'abstract_authors_list':abstract_authors_list})

        if idx % 10000 == 0:
            print('idx', idx)

        if idx % portion_size == 0 and len(pubmed_portion)>0:
            # save the pubmed portion
            with open(f'pubmed_portions_1/pubmed_portion_{counter}.json', 'w') as fp:
                json.dump(pubmed_portion, fp)        
           
            pubmed_portion = []
            counter += 1
    except: 
        pass
# Out:
# ...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\aiohttp\streams.py:315, in StreamReader._wait(self, func_name)
#     314     with self._timer:
# --> 315         await waiter
#     316 finally:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\fsspec\asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# ...

# %%
# Data
dl = data.deep_learning.dropna()
covid_19 = data.covid_19.dropna()
human_connectome = data.human_connectome.dropna()
virtual_reality = data.virtual_reality.dropna()
brain_machine_interfaces = data.brain_machine_interfaces.dropna()
electroactive_polymers = data.electroactive_polymers.dropna()
pedot_electrodes = data.pedot_electrodes.dropna()
neuroprosthetics = data.neuroprosthetics.dropna()

texts = list(pd.concat([dl, covid_19, 
                        human_connectome, virtual_reality, 
                        brain_machine_interfaces, electroactive_polymers, 
                        pedot_electrodes, neuroprosthetics]).unique())

"""texts = list(pd.concat([data.deep_learning, data.covid_19, 
                        data.human_connectome, data.virtual_reality, 
                        data.brain_machine_interfaces, data.electroactive_polymers, 
                        data.pedot_electrodes, data.neuroprosthetics]).unique())"""

print("Data:\n", texts[:1], "\n")


# Cleared Data
texts = [preprocess_text(x) for x in texts]

print("Cleared Data:\n", texts[:1])
