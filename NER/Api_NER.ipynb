# %% [markdown]
# ### **Import Libraries**

# %%
import xml.etree.ElementTree as ET
import requests
import json
import os
import pandas as pd

# %% [markdown]
# ### **Dataset**

# %%
def parse_ddi_corpus(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    sentences = []
    entities = []

    for sentence in root.iter('sentence'):
        sent_text = sentence.attrib['text']
        sent_entities = []

        for entity in sentence.iter('entity'):
            ent_text = entity.attrib['text']
            ent_type = entity.attrib['type']
            char_offset = entity.attrib['charOffset']
            start, end = map(int, char_offset.split('-'))
            
            sent_entities.append({
                'text': ent_text,
                'type': ent_type,
                'start': start,
                'end': end
            })

        sentences.append(sent_text)
        entities.append(sent_entities)

    return sentences, entities

# %%
def bio_tagging(sent_text, sent_entities):
    tokens = sent_text.split()  # Tokenizing by spaces for simplicity; you can use a tokenizer here
    tags = ['O'] * len(tokens)  # Initialize all tags as 'O'
    
    for entity in sent_entities:
        entity_start = entity['start']
        entity_end = entity['end']
        entity_type = entity['type']

        # Iterate over the tokens and update the BIO tags
        current_pos = 0
        for i, token in enumerate(tokens):
            token_start = sent_text.find(token, current_pos)
            token_end = token_start + len(token) - 1
            current_pos = token_end + 1

            # Assign 'B' if the token is the start of an entity, 'I' for inside entity
            if entity_start <= token_start <= entity_end:
                if tags[i] == 'O':  # Only update if it's currently 'O'
                    if token_start == entity_start:
                        tags[i] = f'B-{entity_type}'
                    else:
                        tags[i] = f'I-{entity_type}'

    return tokens, tags

# %%
def process_all_files_in_directory(directory):
    all_results = []
    
    # Iterate through all XML files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".xml"):
            file_path = os.path.join(directory, filename)
            # print(f'Processing {file_path}')
            
            # Parse the file and get sentences and entities
            sentences, entities = parse_ddi_corpus(file_path)
            
            # BIO tag each sentence
            for i, sent_text in enumerate(sentences):
               
                sent_entities = entities[i]
                # print(sent_entities)
                # print(type(sent_entities))
                tokens, tags = bio_tagging(sent_text, sent_entities)
                
                # Store the results
                all_results.append({
                    'sentence': sent_text,
                    'entity': sent_entities,
                    'tokens': tokens,
                    'tags': tags
                })
    
    return all_results

# %%
train_directory = '../DDICorpus/Train/DrugBank'
train_results = process_all_files_in_directory(train_directory)
train_directory_2 = '../DDICorpus/Train/MedLine'
train_results_2 = process_all_files_in_directory(train_directory_2)
train_results.extend(train_results_2)
print(len(train_results))  # Check the length of the train results
# Out:
# 6967

# %%
for result in train_results:
    print(f"Sentence: {result['sentence']}")
    print(f"BIO Tags: {result['tags']}")
    print(f"Entities: {result['entity']}")
    print()
# Out:
# Sentence: No drug, nutritional supplement, food or herb interactions have yet been reported.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: No formal drug/drug interaction studies with Plenaxis were performed.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# Entities: [{'text': 'Plenaxis', 'type': 'brand', 'start': 45, 'end': 52}]
#
# Sentence: Cytochrome P-450 is not known to be involved in the metabolism of Plenaxis.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# Entities: [{'text': 'Plenaxis', 'type': 'brand', 'start': 66, 'end': 73}]
#
# Sentence: Plenaxis is highly bound to plasma proteins (96 to 99%).
# BIO Tags: ['B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Plenaxis', 'type': 'brand', 'start': 0, 'end': 7}]
#
# Sentence: Laboratory Tests Response to Plenaxis should be monitored by measuring serum total testosterone concentrations just prior to administration on Day 29 and every 8 weeks thereafter.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Plenaxis', 'type': 'brand', 'start': 29, 'end': 36}, {'text': 'testosterone', 'type': 'drug', 'start': 83, 'end': 94}]
#
# Sentence: Serum transaminase levels should be obtained before starting treatment with Plenaxis and periodically during treatment.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Plenaxis', 'type': 'brand', 'start': 76, 'end': 83}]
#
# Sentence: Periodic measurement of serum PSA levels may also be considered.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Formal drug interaction studies have not been conducted with ORENCIA.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# Entities: [{'text': 'ORENCIA', 'type': 'brand', 'start': 61, 'end': 67}]
#
# Sentence: Population pharmacokinetic analyses revealed that MTX, NSAIDs, corticosteroids, and TNF blocking agents did not influence abatacept clearance.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'B-group', 'B-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'MTX', 'type': 'drug', 'start': 50, 'end': 52}, {'text': 'NSAIDs', 'type': 'group', 'start': 55, 'end': 60}, {'text': 'corticosteroids', 'type': 'group', 'start': 63, 'end': 77}, {'text': 'TNF blocking agents', 'type': 'group', 'start': 84, 'end': 102}, {'text': 'abatacept', 'type': 'drug', 'start': 122, 'end': 130}]
#
# Sentence: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, hydroxychloroquine, leflunomide, sulfasalazine, and anakinra.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'B-drug', 'B-group', 'B-group', 'B-group', 'I-group', 'I-group', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'ORENCIA', 'type': 'brand', 'start': 115, 'end': 121}, {'text': 'MTX', 'type': 'drug', 'start': 124, 'end': 126}, {'text': 'NSAIDs', 'type': 'group', 'start': 129, 'end': 134}, {'text': 'corticosteroids', 'type': 'group', 'start': 137, 'end': 151}, {'text': 'TNF blocking agents', 'type': 'group', 'start': 154, 'end': 172}, {'text': 'azathioprine', 'type': 'drug', 'start': 175, 'end': 186}, {'text': 'chloroquine', 'type': 'drug', 'start': 189, 'end': 199}, {'text': 'gold', 'type': 'drug', 'start': 202, 'end': 205}, {'text': 'hydroxychloroquine', 'type': 'drug', 'start': 208, 'end': 225}, {'text': 'leflunomide', 'type': 'drug', 'start': 228, 'end': 238}, {'text': 'sulfasalazine', 'type': 'drug', 'start': 241, 'end': 253}, {'text': 'anakinra', 'type': 'drug', 'start': 260, 'end': 267}]
#
# Sentence: Concurrent administration of a TNF antagonist with ORENCIA has been associated with an increased risk of serious infections and no significant additional efficacy over use of the TNF antagonists alone.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O']
# Entities: [{'text': 'TNF antagonist', 'type': 'group', 'start': 31, 'end': 44}, {'text': 'ORENCIA', 'type': 'brand', 'start': 51, 'end': 57}, {'text': 'TNF antagonists', 'type': 'group', 'start': 179, 'end': 193}]
#
# Sentence: Concurrent therapy with ORENCIA and TNF antagonists is not recommended.
# BIO Tags: ['O', 'O', 'O', 'B-brand', 'O', 'B-group', 'I-group', 'O', 'O', 'O']
# Entities: [{'text': 'ORENCIA', 'type': 'brand', 'start': 24, 'end': 30}, {'text': 'TNF antagonists', 'type': 'group', 'start': 36, 'end': 50}]
#
# Sentence: There is insufficient experience to assess the safety and efficacy of ORENCIA administered concurrently with anakinra, and therefore such use is not recommended.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'ORENCIA', 'type': 'brand', 'start': 70, 'end': 76}, {'text': 'anakinra', 'type': 'drug', 'start': 109, 'end': 116}]
#
# Sentence: Formal drug interaction studies with Abciximab have not been conducted.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Abciximab', 'type': 'drug', 'start': 37, 'end': 45}]
#
# Sentence: Abciximab has been administered to patients with ischemic heart disease treated concomitantly with a broad range of medications used in the treatment of angina myocardial infarction and hypertension.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Abciximab', 'type': 'drug', 'start': 0, 'end': 8}]
#
# Sentence: These medications have included heparin, warfarin, beta-adrenergic receptor blockers, calcium channel antagonists, angiotensin converting enzyme inhibitors, intravenous and oral nitrates, ticlopidine, and aspirin.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'B-group', 'B-drug', 'O', 'B-brand']
# Entities: [{'text': 'heparin', 'type': 'drug', 'start': 32, 'end': 38}, {'text': 'warfarin', 'type': 'drug', 'start': 41, 'end': 48}, {'text': 'beta-adrenergic receptor blockers', 'type': 'group', 'start': 51, 'end': 83}, {'text': 'calcium channel antagonists', 'type': 'group', 'start': 86, 'end': 112}, {'text': 'angiotensin converting enzyme inhibitors', 'type': 'group', 'start': 115, 'end': 154}, {'text': 'nitrates', 'type': 'group', 'start': 178, 'end': 185}, {'text': 'ticlopidine', 'type': 'drug', 'start': 188, 'end': 198}, {'text': 'aspirin', 'type': 'brand', 'start': 205, 'end': 211}]
#
# Sentence: Heparin, other anticoagulants, thrombolytics, and anti platelet agents are associated with an increase in bleeding.
# BIO Tags: ['B-drug', 'O', 'B-group', 'B-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Heparin', 'type': 'drug', 'start': 0, 'end': 6}, {'text': 'anticoagulants', 'type': 'group', 'start': 15, 'end': 28}, {'text': 'thrombolytics', 'type': 'group', 'start': 31, 'end': 43}, {'text': 'anti platelet agents', 'type': 'group', 'start': 50, 'end': 69}]
#
# Sentence: Patients with HACA titers may have allergic or hypersensitivity reactions when treated with other diagnostic or therapeutic monoclonal antibodies.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'B-group', 'B-group', 'I-group']
# Entities: [{'text': 'diagnostic monoclonal antibodies', 'type': 'group', 'start': 98, 'end': 107}, {'text': 'diagnostic monoclonal antibodies', 'type': 'group', 'start': 124, 'end': 144}, {'text': 'therapeutic monoclonal antibodies', 'type': 'group', 'start': 112, 'end': 144}]
#
# Sentence: The concomitant intake of alcohol and Acamprosate does not affect the pharmacokinetics of either alcohol or acamprosate.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'alcohol', 'type': 'drug', 'start': 26, 'end': 32}, {'text': 'Acamprosate', 'type': 'drug', 'start': 38, 'end': 48}, {'text': 'alcohol', 'type': 'drug', 'start': 97, 'end': 103}, {'text': 'acamprosate', 'type': 'drug', 'start': 108, 'end': 118}]
#
# Sentence: Pharmacokinetic studies indicate that administration of disulfiram or diazepam does not affect the pharmacokinetics of acamprosate.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'disulfiram', 'type': 'drug', 'start': 56, 'end': 65}, {'text': 'diazepam', 'type': 'drug', 'start': 70, 'end': 77}, {'text': 'acamprosate', 'type': 'drug', 'start': 119, 'end': 129}]
#
# Sentence: Co-administration of naltrexone with Acamprosate produced a 25% increase in AUC and a 33% increase in the Cmax of acamprosate.
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'naltrexone', 'type': 'drug', 'start': 21, 'end': 30}, {'text': 'Acamprosate', 'type': 'drug', 'start': 37, 'end': 47}, {'text': 'acamprosate', 'type': 'drug', 'start': 114, 'end': 124}]
#
# Sentence: No adjustment of dosage is recommended in such patients.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The pharmacokinetics of naltrexone and its major metabolite 6-beta-naltrexol were unaffected following co-administration with Acamprosate.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug_n', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'naltrexone', 'type': 'drug', 'start': 24, 'end': 33}, {'text': '6-beta-naltrexol', 'type': 'drug_n', 'start': 60, 'end': 75}, {'text': 'Acamprosate', 'type': 'drug', 'start': 126, 'end': 136}]
#
# Sentence: Other concomitant therapies: In clinical trials, the safety profile in subjects treated with Acamprosate concomitantly with anxiolytics, hypnotics and sedatives (including benzodiazepines), or non-opioid analgesics was similar to that of subjects taking placebo with these concomitant medications.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'B-group', 'B-group', 'O', 'B-group', 'O', 'B-group', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acamprosate', 'type': 'drug', 'start': 93, 'end': 103}, {'text': 'anxiolytics', 'type': 'group', 'start': 124, 'end': 134}, {'text': 'hypnotics', 'type': 'group', 'start': 137, 'end': 145}, {'text': 'sedatives', 'type': 'group', 'start': 151, 'end': 159}, {'text': 'benzodiazepines', 'type': 'group', 'start': 172, 'end': 186}, {'text': 'non-opioid analgesics', 'type': 'group', 'start': 193, 'end': 213}]
#
# Sentence: Patients taking Acamprosate concomitantly with antidepressants more commonly reported both weight gain and weight loss, compared with patients taking either medication alone.
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acamprosate', 'type': 'drug', 'start': 16, 'end': 26}, {'text': 'antidepressants', 'type': 'group', 'start': 47, 'end': 61}]
#
# Sentence: Certain drugs tend to produce hyperglycemia and may lead to loss of blood glucose control.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'B-group', 'B-group', 'B-group', 'B-group', 'I-group', 'B-group', 'O', 'B-group', 'B-drug', 'B-drug', 'I-drug', 'B-group', 'B-group', 'I-group', 'I-group', 'O', 'B-drug']
# Entities: [{'text': 'thiazides', 'type': 'group', 'start': 24, 'end': 32}, {'text': 'diuretics', 'type': 'group', 'start': 44, 'end': 52}, {'text': 'corticosteroids', 'type': 'group', 'start': 55, 'end': 69}, {'text': 'phenothiazines', 'type': 'group', 'start': 72, 'end': 85}, {'text': 'thyroid products', 'type': 'group', 'start': 88, 'end': 103}, {'text': 'estrogens', 'type': 'group', 'start': 106, 'end': 114}, {'text': 'contraceptives', 'type': 'group', 'start': 122, 'end': 135}, {'text': 'phenytoin', 'type': 'drug', 'start': 138, 'end': 146}, {'text': 'nicotinic acid', 'type': 'drug', 'start': 149, 'end': 162}, {'text': 'sympathomimetics', 'type': 'group', 'start': 165, 'end': 180}, {'text': 'calcium channel-blocking drugs', 'type': 'group', 'start': 183, 'end': 212}, {'text': 'isoniazid', 'type': 'drug', 'start': 219, 'end': 227}]
#
# Sentence: When such drugs are administered to a patient receiving Acarbose, the patient should be closely observed for loss of blood glucose control.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 56, 'end': 63}]
#
# Sentence: When such drugs are withdrawn from patients receiving Acarbose in combination with sulfonylureas or insulin, patients should be observed closely for any evidence of hypoglycemia.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 54, 'end': 61}, {'text': 'sulfonylureas', 'type': 'group', 'start': 83, 'end': 95}, {'text': 'insulin', 'type': 'drug', 'start': 100, 'end': 106}]
#
# Sentence: Intestinal adsorbents (e. g., charcoal) and digestive enzyme preparations containing carbohydrate-splitting enzymes (e. g., amylase, pancreatin) may reduce the effect of Acarbose and should not be taken concomitantly.
# BIO Tags: ['B-group', 'I-group', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Intestinal adsorbents', 'type': 'group', 'start': 0, 'end': 20}, {'text': 'charcoal', 'type': 'drug', 'start': 30, 'end': 37}, {'text': 'digestive enzyme preparations', 'type': 'group', 'start': 44, 'end': 72}, {'text': 'amylase', 'type': 'drug', 'start': 124, 'end': 130}, {'text': 'pancreatin', 'type': 'drug', 'start': 133, 'end': 142}, {'text': 'Acarbose', 'type': 'drug', 'start': 170, 'end': 177}]
#
# Sentence: Acarbose has been shown to change the bioavailabillty digoxin when they are co-administered, which may require digoxin dose adjustment.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 0, 'end': 7}, {'text': 'digoxin', 'type': 'drug', 'start': 54, 'end': 60}, {'text': 'digoxin', 'type': 'drug', 'start': 111, 'end': 117}]
#
# Sentence: Studies in healthy volunteers have shown that Acarbose has no effect on either the pharmacokinetics or pharmacodynamics of digoxin, nifedipine, propranolol, or ranitidine.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 46, 'end': 53}, {'text': 'digoxin', 'type': 'drug', 'start': 123, 'end': 129}, {'text': 'nifedipine', 'type': 'drug', 'start': 132, 'end': 141}, {'text': 'propranolol', 'type': 'drug', 'start': 144, 'end': 154}, {'text': 'ranitidine', 'type': 'drug', 'start': 160, 'end': 169}]
#
# Sentence: Acarbose did not interfere with the absorption or disposition of the sulfonylurea glyburide in diabetic patients.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 0, 'end': 7}, {'text': 'sulfonylurea', 'type': 'drug', 'start': 69, 'end': 80}, {'text': 'glyburide', 'type': 'drug', 'start': 82, 'end': 90}]
#
# Sentence: Acarbose may affect digoxin bioavailabillty and may require dose adjustment of digoxin by 16% (90% confidence interval: 8-23%), decrease mean C max digoxin by 26% (90% confidence interval: 16-34%) and decrease mean trough concentrations of digoxin by 9% (90% confidence limit: 19% decrease to 2% increase).
# BIO Tags: ['B-drug', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 0, 'end': 7}, {'text': 'digoxin', 'type': 'drug', 'start': 20, 'end': 26}, {'text': 'digoxin', 'type': 'drug', 'start': 79, 'end': 85}, {'text': 'digoxin', 'type': 'drug', 'start': 148, 'end': 154}, {'text': 'digoxin', 'type': 'drug', 'start': 240, 'end': 246}]
#
# Sentence: The amount of metformin absorbed while taking Acarbose was bioequivalent to the amount absorbed when taking placebo, as indicated by the plasma AUC values.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'metformin', 'type': 'drug', 'start': 14, 'end': 22}, {'text': 'Acarbose', 'type': 'drug', 'start': 46, 'end': 53}]
#
# Sentence: However, the peak plasma level of metformin was reduced by approximately 20% when taking Acarbose due to a slight delay in the absorption of metformin.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'metformin', 'type': 'drug', 'start': 34, 'end': 42}, {'text': 'Acarbose', 'type': 'drug', 'start': 89, 'end': 96}, {'text': 'metformin', 'type': 'drug', 'start': 141, 'end': 149}]
#
# Sentence: There is little if any clinically significant interaction between Acarbose and metformin.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'Acarbose', 'type': 'drug', 'start': 66, 'end': 73}, {'text': 'metformin', 'type': 'drug', 'start': 79, 'end': 87}]
#
# Sentence: Catecholamine-depleting drugs, such as reserpine, may have an additive effect when given with beta-blocking agents.
# BIO Tags: ['B-group', 'I-group', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group']
# Entities: [{'text': 'Catecholamine-depleting drugs', 'type': 'group', 'start': 0, 'end': 28}, {'text': 'reserpine', 'type': 'drug', 'start': 39, 'end': 47}, {'text': 'beta-blocking agents', 'type': 'group', 'start': 94, 'end': 113}]
#
# Sentence: Patients treated with acebutolol plus catecholamine depletors should, therefore, be observed closely for evidence of marked bradycardia or hypotension which may present as vertigo, syncope/presyncope, or orthostatic changes in blood pressure without compensatory tachycardia.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'acebutolol', 'type': 'drug', 'start': 22, 'end': 31}, {'text': 'catecholamine depletors', 'type': 'group', 'start': 38, 'end': 60}]
#
# Sentence: Exaggerated hypertensive responses have been reported from the combined use of beta-adrenergic antagonists and alpha-adrenergic stimulants, including those contained in proprietary cold remedies and vasoconstrictive nasal drops.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'beta-adrenergic antagonists', 'type': 'group', 'start': 79, 'end': 105}, {'text': 'alpha-adrenergic stimulants', 'type': 'group', 'start': 111, 'end': 137}]
#
# Sentence: Patients receiving beta-blockers should be warned of this potential hazard.
# BIO Tags: ['O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'beta-blockers', 'type': 'group', 'start': 19, 'end': 31}]
#
# Sentence: Blunting of the antihypertensive effect of beta-adrenoceptor blocking agents by nonsteroidal anti-inflammatory drugs has been reported.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O']
# Entities: [{'text': 'beta-adrenoceptor blocking agents', 'type': 'group', 'start': 43, 'end': 75}, {'text': 'nonsteroidal anti-inflammatory drugs', 'type': 'group', 'start': 80, 'end': 115}]
#
# Sentence: No significant interactions with digoxin, hydrochlorothiazide, hydralazine, sulfinpyrazone, oral contraceptives, tolbutamide, or warfarin have been observed.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-group', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'digoxin', 'type': 'drug', 'start': 33, 'end': 39}, {'text': 'hydrochlorothiazide', 'type': 'drug', 'start': 42, 'end': 60}, {'text': 'hydralazine', 'type': 'drug', 'start': 63, 'end': 73}, {'text': 'sulfinpyrazone', 'type': 'drug', 'start': 76, 'end': 89}, {'text': 'contraceptives', 'type': 'group', 'start': 97, 'end': 110}, {'text': 'tolbutamide', 'type': 'drug', 'start': 113, 'end': 123}, {'text': 'warfarin', 'type': 'drug', 'start': 129, 'end': 136}]
#
# Sentence: DIAMOX modifies phenytoin metabolism with increased serum levels of phenytoin.
# BIO Tags: ['B-brand', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'DIAMOX', 'type': 'brand', 'start': 0, 'end': 5}, {'text': 'phenytoin', 'type': 'drug', 'start': 16, 'end': 24}, {'text': 'phenytoin', 'type': 'drug', 'start': 68, 'end': 76}]
#
# Sentence: This may increase or enhance the occurrence of osteomalacia in some patients receiving chronic phenytoin therapy.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'phenytoin', 'type': 'drug', 'start': 95, 'end': 103}]
#
# Sentence: Caution is advised in patients receiving chronic concomitant therapy.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: By decreasing the gastrointestinal absorption of primidone, DIAMOX may decrease serum concentrations of primidone and its metabolites, with a consequent possible decrease in anticonvulsant effect.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'primidone', 'type': 'drug', 'start': 49, 'end': 57}, {'text': 'DIAMOX', 'type': 'brand', 'start': 60, 'end': 65}, {'text': 'primidone', 'type': 'drug', 'start': 104, 'end': 112}]
#
# Sentence: Caution is advised when beginning, discontinuing, or changing the dose of DIAMOX in patients receiving primidone.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'DIAMOX', 'type': 'brand', 'start': 74, 'end': 79}, {'text': 'primidone', 'type': 'drug', 'start': 103, 'end': 111}]
#
# Sentence: Because of possible additive effects with other carbonic anhydrase inhibitors, concomitant use is not advisable.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'carbonic anhydrase inhibitors', 'type': 'group', 'start': 48, 'end': 76}]
#
# Sentence: Acetazolamide may increase the effects of other folic acid antagonists.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'folic acid antagonists', 'type': 'group', 'start': 48, 'end': 69}]
#
# Sentence: Acetazolamide may increase or decrease blood glucose levels.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}]
#
# Sentence: Consideration should be taken in patients being treated with antidiabetic agents.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'antidiabetic', 'type': 'drug', 'start': 61, 'end': 72}]
#
# Sentence: Acetazolamide decreases urinary excretion of amphetamine and may enhance the magnitude and duration of their effect.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'amphetamine', 'type': 'drug', 'start': 45, 'end': 55}]
#
# Sentence: Acetazolamide reduces urinary excretion of quinidine and may enhance its effect.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'quinidine', 'type': 'drug', 'start': 43, 'end': 51}]
#
# Sentence: Acetazolamide may prevent the urinary antiseptic effect of methenamine.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'methenamine', 'type': 'drug', 'start': 59, 'end': 69}]
#
# Sentence: Acetazolamide increases lithium excretion and the lithium may be decreased.
# BIO Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'lithium', 'type': 'drug', 'start': 24, 'end': 30}, {'text': 'lithium', 'type': 'drug', 'start': 50, 'end': 56}]
#
# Sentence: Acetazolamide and sodium bicarbonate used concurrently increases the risk of renal calculus formation.
# BIO Tags: ['B-drug', 'O', 'B-drug', 'I-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'sodium bicarbonate', 'type': 'drug', 'start': 18, 'end': 35}]
#
# Sentence: Acetazolamide may elevate cyclosporine levels.
# BIO Tags: ['B-drug', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'Acetazolamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'cyclosporine', 'type': 'drug', 'start': 26, 'end': 37}]
#
# Sentence: Concomitant use with iron                    supplements may result in the reduced absorption of iron.
# BIO Tags: ['O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'iron supplement', 'type': 'group', 'start': 21, 'end': 35}, {'text': 'iron', 'type': 'drug', 'start': 78, 'end': 81}]
#
# Sentence: Co-administration of probenecid with acyclovir has been shown to increase the mean half-life and the area under the concentration-time curve.
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'probenecid', 'type': 'drug', 'start': 21, 'end': 30}, {'text': 'acyclovir', 'type': 'drug', 'start': 37, 'end': 45}]
#
# Sentence: Urinary excretion and renal clearance were correspondingly reduced.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The clinical effects of this combination have not been studied.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Ethanol:Clinical evidence has shown that etretinate can be formed with concurrent ingestion of acitretin and ethanol.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'Ethanol', 'type': 'drug', 'start': 0, 'end': 6}, {'text': 'etretinate', 'type': 'drug', 'start': 41, 'end': 50}, {'text': 'acitretin', 'type': 'drug', 'start': 95, 'end': 103}, {'text': 'ethanol', 'type': 'drug', 'start': 109, 'end': 115}]
#
# Sentence: Glibenclamide: In a study of 7 healthy male volunteers, acitretin treatment potentiated the blood glucose lowering effect of glibenclamide (a sulfonylurea similar to chlorpropamide) in 3 of the 7 subjects.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Glibenclamide', 'type': 'drug', 'start': 0, 'end': 12}, {'text': 'acitretin', 'type': 'drug', 'start': 56, 'end': 64}, {'text': 'glibenclamide', 'type': 'drug', 'start': 125, 'end': 137}, {'text': 'sulfonylurea', 'type': 'group', 'start': 142, 'end': 153}, {'text': 'chlorpropamide', 'type': 'drug', 'start': 166, 'end': 179}]
#
# Sentence: Repeating the study with 6 healthy male volunteers in the absence of glibenclamide did not detect an effect of acitretin on glucose tolerance.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'glibenclamide', 'type': 'drug', 'start': 69, 'end': 81}, {'text': 'acitretin', 'type': 'drug', 'start': 111, 'end': 119}]
#
# Sentence: Careful supervision of diabetic patients under treatment with Soriatane is recommended.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# Entities: [{'text': 'Soriatane', 'type': 'brand', 'start': 62, 'end': 70}]
#
# Sentence: Hormonal Contraceptives: It has not been established if there is a pharmacokinetic interaction between acitretin and combined oral contraceptives.
# BIO Tags: ['B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'I-group']
# Entities: [{'text': 'Hormonal Contraceptives', 'type': 'group', 'start': 0, 'end': 22}, {'text': 'acitretin', 'type': 'drug', 'start': 103, 'end': 111}, {'text': 'combined oral contraceptives', 'type': 'group', 'start': 117, 'end': 144}]
#
# Sentence: However, it has been established that acitretin interferes with the contraceptive effect of microdosed progestin minipill preparations.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O']
# Entities: [{'text': 'acitretin', 'type': 'drug', 'start': 38, 'end': 46}, {'text': 'progestin', 'type': 'drug', 'start': 103, 'end': 111}]
#
# Sentence: Microdosed minipill progestin preparations are not recommended for use with Soriatane.
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'progestin', 'type': 'drug', 'start': 20, 'end': 28}, {'text': 'Soriatane', 'type': 'drug', 'start': 76, 'end': 84}]
#
# Sentence: It is not known whether other progestational contraceptives, such as implants and injectables, are adequate methods of contraception during acitretin therapy.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'progestational contraceptives', 'type': 'group', 'start': 30, 'end': 58}, {'text': 'acitretin', 'type': 'drug', 'start': 140, 'end': 148}]
#
# Sentence: Methotrexate: An increased risk of hepatitis has been reported to result from combined use of methotrexate and etretinate.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'Methotrexate', 'type': 'drug', 'start': 0, 'end': 11}, {'text': 'methotrexate', 'type': 'drug', 'start': 94, 'end': 105}, {'text': 'etretinate', 'type': 'drug', 'start': 111, 'end': 120}]
#
# Sentence: Consequently, the combination of methotrexate with acitretin is also contraindicated.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'methotrexate', 'type': 'drug', 'start': 33, 'end': 44}, {'text': 'acitretin', 'type': 'drug', 'start': 51, 'end': 59}]
#
# Sentence: Phenytoin: If acitretin is given concurrently with phenytoin, the protein binding of phenytoin may be reduced.
# BIO Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'Phenytoin', 'type': 'drug', 'start': 0, 'end': 8}, {'text': 'acitretin', 'type': 'drug', 'start': 14, 'end': 22}, {'text': 'phenytoin', 'type': 'drug', 'start': 51, 'end': 59}, {'text': 'phenytoin', 'type': 'drug', 'start': 85, 'end': 93}]
#
# Sentence: Tetracyclines: Since both acitretin and tetracyclines can cause increased intracranial pressure, their combined use is contraindicated.
# BIO Tags: ['B-group', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Tetracyclines', 'type': 'group', 'start': 0, 'end': 12}, {'text': 'acitretin', 'type': 'drug', 'start': 26, 'end': 34}, {'text': 'tetracyclines', 'type': 'group', 'start': 40, 'end': 52}]
#
# Sentence: Vitamin A and oral retinoids: Concomitant administration of vitamin A and/or other oral retinoids with acitretin must be avoided because of the risk of hypervitaminosis A.
# BIO Tags: ['B-group', 'I-group', 'O', 'O', 'B-group', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Vitamin A', 'type': 'group', 'start': 0, 'end': 8}, {'text': 'retinoids', 'type': 'group', 'start': 19, 'end': 27}, {'text': 'vitamin A', 'type': 'group', 'start': 60, 'end': 68}, {'text': 'retinoids', 'type': 'group', 'start': 88, 'end': 96}, {'text': 'acitretin', 'type': 'drug', 'start': 103, 'end': 111}]
#
# Sentence: Other: There appears to be no pharmacokinetic interaction between acitretin and cimetidine, digoxin, or glyburide.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'acitretin', 'type': 'drug', 'start': 66, 'end': 74}, {'text': 'cimetidine', 'type': 'drug', 'start': 80, 'end': 89}, {'text': 'digoxin', 'type': 'drug', 'start': 92, 'end': 98}, {'text': 'glyburide', 'type': 'drug', 'start': 104, 'end': 112}]
#
# Sentence: Investigations into the effect of acitretin on the protein binding of anticoagulants of the coumarin type (warfarin) revealed no interaction.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'acitretin', 'type': 'drug', 'start': 34, 'end': 42}, {'text': 'anticoagulants of the coumarin type', 'type': 'group', 'start': 70, 'end': 104}, {'text': 'warfarin', 'type': 'drug', 'start': 107, 'end': 114}]
#
# Sentence: Laboratory Tests If significant abnormal laboratory results are obtained, either dosage reduction with careful monitoring or treatment discontinuation is recommended, depending on clinical judgement.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Blood Sugar: Some patients receiving retinoids have experienced problems with blood sugar control.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'retinoids', 'type': 'group', 'start': 37, 'end': 45}]
#
# Sentence: In addition, new cases of diabetes have been diagnosed during retinoid therapy, including diabetic ketoacidosis.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'retinoid', 'type': 'group', 'start': 62, 'end': 69}]
#
# Sentence: In diabetics, blood-sugar levels should be monitored very carefully.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Lipids: In clinical studies, the incidence of hypertriglyceridemia was 66%, hypercholesterolemia was 33% and that of decreased HDL was 40%.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Pretreatment and follow-up measurements should be obtained under fasting conditions.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: It is recommended that these tests be performed weekly or every other week until the lipid response to Soriatane has stabilized.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# Entities: [{'text': 'Soriatane', 'type': 'brand', 'start': 103, 'end': 111}]
#
# Sentence: Liver Function Tests: Elevations of AST (SGOT), ALT (SGPT) or LDH were experienced by approximately 1 in 3 patients treated with Soriatane.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# Entities: [{'text': 'Soriatane', 'type': 'brand', 'start': 129, 'end': 137}]
#
# Sentence: It is recommended that these tests be performed prior to initiation of Soriatane therapy, at 1- to 2-week intervals until stable and thereafter at intervals as clinically indicated.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Soriatane', 'type': 'brand', 'start': 71, 'end': 79}]
#
# Sentence: Methotrexate: HUMIRA has been studied in rheumatoid arthritis patients taking concomitant MTX.
# BIO Tags: ['B-drug', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'Methotrexate', 'type': 'drug', 'start': 0, 'end': 11}, {'text': 'HUMIRA', 'type': 'brand', 'start': 14, 'end': 19}, {'text': 'MTX', 'type': 'drug', 'start': 90, 'end': 92}]
#
# Sentence: The data do not suggest the need for dose adjustment of either HUMIRA or MTX.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'B-drug']
# Entities: [{'text': 'HUMIRA', 'type': 'brand', 'start': 63, 'end': 68}, {'text': 'MTX', 'type': 'drug', 'start': 73, 'end': 75}]
#
# Sentence: Anakinra: Concurrent administration of anakinra (an interleukin-1 antagonist) and another TNF-blocking agent has been associated with an increased risk of serious infections, an increased risk of neutropenia and no additional benefit compared to these medicinal products alone.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Anakinra', 'type': 'drug', 'start': 0, 'end': 7}, {'text': 'anakinra', 'type': 'drug', 'start': 39, 'end': 46}, {'text': 'interleukin-1 antagonist', 'type': 'group', 'start': 52, 'end': 75}, {'text': 'TNF-blocking agent', 'type': 'group', 'start': 90, 'end': 107}]
#
# Sentence: The safety and efficacy of anakinra used in combination with HUMIRA has not been studied.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'anakinra', 'type': 'drug', 'start': 27, 'end': 34}, {'text': 'HUMIRA', 'type': 'brand', 'start': 61, 'end': 66}]
#
# Sentence: Therefore the, combination of anakinra with other TNF-blocking agents, including HUMIRA, may also result i n similar toxicities.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'B-group', 'I-group', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'anakinra', 'type': 'drug', 'start': 30, 'end': 37}, {'text': 'TNF-blocking agents', 'type': 'group', 'start': 50, 'end': 68}, {'text': 'HUMIRA', 'type': 'brand', 'start': 81, 'end': 86}]
#
# Sentence: As DIFFERIN Gel has the potential to produce local irritation in some patients, concomitant use of other potentially irritating topical products (medicated or abrasive soaps and cleansers, soaps and cosmetics that have a strong drying effect, and products with high concentrations of alcohol, astringents, spices or lime) should be approached with caution.
# BIO Tags: ['O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'DIFFERIN', 'type': 'brand', 'start': 3, 'end': 10}]
#
# Sentence: Particular caution should be exercised in using preparations containing sulfur, resorcinol, or salicylic acid in combination with DIFFERIN Gel.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'B-drug', 'I-drug', 'O', 'O', 'O', 'B-brand', 'O']
# Entities: [{'text': 'sulfur', 'type': 'drug', 'start': 72, 'end': 77}, {'text': 'resorcinol', 'type': 'drug', 'start': 80, 'end': 89}, {'text': 'salicylic acid', 'type': 'drug', 'start': 95, 'end': 108}, {'text': 'DIFFERIN', 'type': 'brand', 'start': 130, 'end': 137}]
#
# Sentence: If these preparations have been used it is advisable not to start therapy with DIFFERIN Gel until the effects of such preparations in the skin have subsided.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'DIFFERIN', 'type': 'brand', 'start': 79, 'end': 86}]
#
# Sentence: Before using this medication, tell your doctor or pharmacist of all prescription and nonprescription products you may use, especially of: aminoglycosides (e.g., gentamicin, amikacin), amphotericin B, cyclosporine, non-steroidal anti-inflammatory drugs (e.g., ibuprofen), tacrolimus, vancomycin.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'B-drug', 'B-drug', 'I-drug', 'B-drug', 'B-group', 'I-group', 'O', 'O', 'B-drug', 'B-drug', 'B-drug']
# Entities: [{'text': 'aminoglycosides', 'type': 'group', 'start': 138, 'end': 152}, {'text': 'gentamicin', 'type': 'drug', 'start': 161, 'end': 170}, {'text': 'amikacin', 'type': 'drug', 'start': 173, 'end': 180}, {'text': 'amphotericin B', 'type': 'drug', 'start': 184, 'end': 197}, {'text': 'cyclosporine', 'type': 'drug', 'start': 200, 'end': 211}, {'text': 'non-steroidal anti-inflammatory', 'type': 'group', 'start': 214, 'end': 244}, {'text': 'ibuprofen', 'type': 'drug', 'start': 259, 'end': 267}, {'text': 'tacrolimus', 'type': 'drug', 'start': 271, 'end': 280}, {'text': 'vancomycin', 'type': 'drug', 'start': 283, 'end': 292}]
#
# Sentence: Do not start or stop any medicine without doctor or pharmacist approval.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Intravenous Adenocard (adenosine) has been effectively administered in the presence of other cardioactive drugs, such as quinidine, beta-adrenergic blocking agents, calcium channel blocking agents, and angiotensin converting enzyme inhibitors, without any change in the adverse reaction profile.
# BIO Tags: ['O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Adenocard', 'type': 'brand', 'start': 12, 'end': 20}, {'text': 'adenosine', 'type': 'drug', 'start': 23, 'end': 31}, {'text': 'quinidine', 'type': 'drug', 'start': 121, 'end': 129}, {'text': 'beta-adrenergic blocking agents', 'type': 'group', 'start': 132, 'end': 162}, {'text': 'calcium channel blocking agents', 'type': 'group', 'start': 165, 'end': 195}, {'text': 'angiotensin converting enzyme inhibitors', 'type': 'group', 'start': 202, 'end': 241}]
#
# Sentence: Digoxin and verapamil use may be rarely associated with ventricular fibrillation when combined with Adenocard.
# BIO Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# Entities: [{'text': 'Digoxin', 'type': 'drug', 'start': 0, 'end': 6}, {'text': 'verapamil', 'type': 'drug', 'start': 12, 'end': 20}, {'text': 'Adenocard', 'type': 'brand', 'start': 100, 'end': 108}]
#
# Sentence: Because of the potential for additive or synergistic depressant effects on the SA and AV nodes, however, Adenocard should be used with caution in the presence of these agents.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Adenocard', 'type': 'brand', 'start': 105, 'end': 113}]
#
# Sentence: The use of Adenocard in patients receiving digitalis may be rarely associated with ventricular fibrillation.
# BIO Tags: ['O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Adenocard', 'type': 'brand', 'start': 11, 'end': 19}, {'text': 'digitalis', 'type': 'group', 'start': 43, 'end': 51}]
#
# Sentence: The effects of adenosine are antagonized by methylxanthines such as caffeine and theophylline.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-group', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'adenosine', 'type': 'drug', 'start': 15, 'end': 23}, {'text': 'methylxanthines', 'type': 'group', 'start': 44, 'end': 58}, {'text': 'caffeine', 'type': 'drug', 'start': 68, 'end': 75}, {'text': 'theophylline', 'type': 'drug', 'start': 81, 'end': 92}]
#
# Sentence: In the presence of these methylxanthines, larger doses of adenosine may be required or adenosine may not be effective.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'methylxanthines', 'type': 'group', 'start': 25, 'end': 39}, {'text': 'adenosine', 'type': 'drug', 'start': 58, 'end': 66}, {'text': 'adenosine', 'type': 'drug', 'start': 87, 'end': 95}]
#
# Sentence: Adenosine effects are potentiated by dipyridamole.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'Adenosine', 'type': 'drug', 'start': 0, 'end': 8}, {'text': 'dipyridamole', 'type': 'drug', 'start': 37, 'end': 48}]
#
# Sentence: Thus, smaller doses of adenosine may be effective in the presence of dipyridamole.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'adenosine', 'type': 'drug', 'start': 23, 'end': 31}, {'text': 'dipyridamole', 'type': 'drug', 'start': 69, 'end': 80}]
#
# Sentence: Carbamazepine has been reported to increase the degree of heart block produced by other agents.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Carbamazepine', 'type': 'drug', 'start': 0, 'end': 12}]
#
# Sentence: As the primary effect of adenosine is to decrease conduction through the A-V node, higher degrees of heart block may be produced in the presence of carbamazepine.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'adenosine', 'type': 'drug', 'start': 25, 'end': 33}, {'text': 'carbamazepine', 'type': 'drug', 'start': 148, 'end': 160}]
#
# Sentence: Co-administration with antifungal agents such as ketoconazole or itraconazole is not recommended.
# BIO Tags: ['O', 'O', 'B-group', 'I-group', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'antifungal agents', 'type': 'group', 'start': 23, 'end': 39}, {'text': 'ketoconazole', 'type': 'drug', 'start': 49, 'end': 60}, {'text': 'itraconazole', 'type': 'drug', 'start': 65, 'end': 76}]
#
# Sentence: Nafazodone, fluvoxamine, cimetidine (consider Xanax dose reduction).
# BIO Tags: ['B-drug', 'B-drug', 'B-drug', 'O', 'B-brand', 'O', 'O']
# Entities: [{'text': 'Nafazodone', 'type': 'drug', 'start': 0, 'end': 9}, {'text': 'fluvoxamine', 'type': 'drug', 'start': 12, 'end': 22}, {'text': 'cimetidine', 'type': 'drug', 'start': 25, 'end': 34}, {'text': 'Xanax', 'type': 'brand', 'start': 46, 'end': 50}]
#
# ...
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug_n', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug_n', 'I-drug_n', 'O', 'B-drug_n', 'I-drug_n', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'angiotensin', 'type': 'drug_n', 'start': 45, 'end': 55}, {'text': 'angiotensin 1', 'type': 'drug_n', 'start': 183, 'end': 195}, {'text': 'angiotensin 2', 'type': 'drug_n', 'start': 201, 'end': 213}, {'text': 'pentagastrin', 'type': 'drug', 'start': 218, 'end': 229}, {'text': 'histamine', 'type': 'drug', 'start': 236, 'end': 244}]
#
# Sentence: It was established that both angiotensins inhibited gastric acid secretion stimulated by pentagastrin but not by histamine.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'pentagastrin', 'type': 'drug', 'start': 89, 'end': 100}, {'text': 'histamine', 'type': 'drug', 'start': 113, 'end': 121}]
#
# Sentence: Comparative analysis of the effects of stimulation and inhibition of cholino- and adrenoreceptors on this inhibitory action of angiotensins suggested the mediation of angiotensin influence through the modulation of cholinergic reactions of parietal cells in the stomach.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug_n', 'O', 'O', 'O', 'O', 'B-drug_n', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'angiotensins', 'type': 'drug_n', 'start': 127, 'end': 138}, {'text': 'angiotensin', 'type': 'drug_n', 'start': 167, 'end': 177}]
#
# Sentence: Interaction of gentamycin and atracurium in anaesthetised horses.
#
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'gentamycin', 'type': 'drug', 'start': 15, 'end': 24}, {'text': 'atracurium', 'type': 'drug', 'start': 30, 'end': 39}]
#
# Sentence: Evoked hind limb digital extensor tension (hoof twitch) was maintained at 40% of baseline for 1 h by atracurium infusion in 7 horses anaesthetised with halothane.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# Entities: [{'text': 'atracurium', 'type': 'drug', 'start': 101, 'end': 110}, {'text': 'halothane', 'type': 'drug', 'start': 152, 'end': 160}]
#
# Sentence: After 1 h, atracurium was discontinued and hoof twitch allowed to recover to 75%.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'atracurium', 'type': 'drug', 'start': 11, 'end': 20}]
#
# Sentence: Atracurium was again given by infusion to maintain 40% twitch for a second hour, then 2 mg gentamycin/kg bwt were given i.v.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Atracurium', 'type': 'drug', 'start': 0, 'end': 9}, {'text': 'gentamycin', 'type': 'drug', 'start': 91, 'end': 100}]
#
# Sentence: Atracurium infusion was continued for a third hour, and then hoof twitch was again allowed to recover spontaneously to 75%.
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Atracurium', 'type': 'drug', 'start': 0, 'end': 9}]
#
# Sentence: Gentamycin reduced twitch strength from 40 +/- 1% (mean +/- sem) to 29 +/- 4% within 7.0 +/- 1.5 min (P = 0.02).
# BIO Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Gentamycin', 'type': 'drug', 'start': 0, 'end': 9}]
#
# Sentence: Twitch gradually returned to pre-gentamycin strength over the course of the next hour.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'gentamycin', 'type': 'drug', 'start': 33, 'end': 42}]
#
# Sentence: Recovery of hoof twitch from 50% to 75% took 7.7 +/- 0.7 min for atracurium alone and 11.5 +/- 2.7 min for atracurium plus gentamycin (P = 0.03).
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# Entities: [{'text': 'atracurium', 'type': 'drug', 'start': 65, 'end': 74}, {'text': 'atracurium', 'type': 'drug', 'start': 107, 'end': 116}, {'text': 'gentamycin', 'type': 'drug', 'start': 123, 'end': 132}]
#
# Sentence: Recovery from 50% twitch to 75% fade recovery took 13.8 +/- 0.8 min for atracurium alone and 13.7 +/- 1.2 min for atracurium plus gentamycin.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'atracurium', 'type': 'drug', 'start': 72, 'end': 81}, {'text': 'atracurium', 'type': 'drug', 'start': 114, 'end': 123}, {'text': 'gentamycin', 'type': 'drug', 'start': 130, 'end': 139}]
#
# Sentence: At 75% recovery of fade, hoof twitch was 87 +/- 3% for atracurium alone and 82 +/- 4% for atracurium plus gentamycin.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# Entities: [{'text': 'atracurium', 'type': 'drug', 'start': 55, 'end': 64}, {'text': 'atracurium', 'type': 'drug', 'start': 90, 'end': 99}, {'text': 'gentamycin', 'type': 'drug', 'start': 106, 'end': 115}]
#
# Sentence: Reversal of the block with edrophonium and subsequent recovery of the horses from anaesthesia were uneventful.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'edrophonium', 'type': 'drug', 'start': 27, 'end': 37}]
#
# Sentence: It was concluded that, although gentamycin did augment the neuromuscular blockade of atracurium, the effect was minimal.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'gentamycin', 'type': 'drug', 'start': 32, 'end': 41}, {'text': 'atracurium', 'type': 'drug', 'start': 85, 'end': 94}]
#
# Sentence: Anticoagulants.
#
# BIO Tags: ['B-group']
# Entities: [{'text': 'Anticoagulants', 'type': 'group', 'start': 0, 'end': 13}]
#
# Sentence: Treatment plans for patients taking anticoagulants can become complicated.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O']
# Entities: [{'text': 'anticoagulants', 'type': 'group', 'start': 36, 'end': 49}]
#
# Sentence: Anticoagulants predispose a patient to bleeding problems.
# BIO Tags: ['B-group', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'Anticoagulants', 'type': 'group', 'start': 0, 'end': 13}]
#
# Sentence: Many drugs used in dentistry cannot be taken concomitantly with these medications.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Administration of lithium prophylaxis.
#
# BIO Tags: ['O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'lithium', 'type': 'drug', 'start': 18, 'end': 24}]
#
# Sentence: Successful prophylaxis of manic-depressive disorder requires more than the prescription of lithium carbonate.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'I-drug']
# Entities: [{'text': 'lithium carbonate', 'type': 'drug', 'start': 91, 'end': 107}]
#
# Sentence: The administrative arrangements in an area of Scotland were accompanied by a 300% increase in the frequency of admissions for mania, whereas in an area of the West Midlands, a large decrease was achieved.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: [Multiple occupational exposure to solvents]
# This article review papers published over the last 20 years on multiple occupational exposure to solvents.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: At low-levels of exposure the toxicokinetic interferences between solvents have generally not been observed in man and presumably a threshold limit exists.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Conversely, at exposure levels close to the "limit values"
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: metabolic interference has sometimes been observed and the behaviour of the biological indicators differs from what would be expected.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Toxicodynamic interference between solvents can give rise to additive, potentiation, synergistic, antagonistic effects.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: For the identification of "limit values", it has generally been suggested in the literature that the possible effects deriving from multiple exposure be considered as additive.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: However, numerous potentiation effects have frequently been reported for combined exposure to substances of widespread use.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: In this paper lists of multiple exposure in which the doses of the substances, the types of interferences and the behaviour of the biological levels have been drawn up and proposed as a tool for easy consultation.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Determinants of cellular sensitivity to topoisomerase-targeting antitumor drugs.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group']
# Entities: [{'text': 'topoisomerase-targeting antitumor drugs', 'type': 'group', 'start': 40, 'end': 78}]
#
# Sentence: It is now clear that topoisomerase activity level is an important determinant of sensitivity to topo drugs.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The regulation of topoisomerases is no doubt complex and multifaceted and is probably accomplished through redundancy at many control levels.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The mechanism(s) of altered topo I expression in certain tumor types is unknown, but may be related to the central importance of topoisomerases in proliferating cell functions (transcription, replication, etc.), and the aberrant and chronic activation of these functions as a result of specific tumorigenic alterations.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Small differences in sensitivity to chemotherapy can have a dramatic effect on cure rates, and therefore subtle cell type-specific differences may be important determinants of drug sensitivity.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Whether abnormal topoisomerase quantity and specific activity are associated with resistance or sensitivity to topoisomerase-targeted chemotherapy in the clinic is now being studied.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Determinants downstream of cleavable complex formation that affect the sensitivity of tumor versus normal cells to topo drugs in particular and DNA-damaging agents in general are little known.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The goal of enhancing selective tumor cell killing relative to the normal cells that are dose limiting may be achieved either by overcoming tumor cell resistance or by protecting normal cells.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Both of these strategies will become more feasible as specific molecular differences between tumor and normal cells are being rapidly identified and new combination therapies that take advantage of these differences are being designed and tested.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: Acid-catalyzed ethanolysis of temazepam in anhydrous and aqueous ethanol solutions.
# BIO Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# Entities: [{'text': 'temazepam', 'type': 'drug', 'start': 30, 'end': 38}, {'text': 'ethanol', 'type': 'drug', 'start': 65, 'end': 71}]
#
# Sentence: The benzodiazepines are a family of anxiolytic and hypnotic drugs.
# BIO Tags: ['O', 'B-group', 'O', 'O', 'O', 'O', 'B-group', 'O', 'B-group', 'I-group']
# Entities: [{'text': 'benzodiazepines', 'type': 'group', 'start': 4, 'end': 18}, {'text': 'anxiolytic', 'type': 'group', 'start': 36, 'end': 45}, {'text': 'hypnotic drugs', 'type': 'group', 'start': 51, 'end': 64}]
#
# Sentence: When taken concurrently with ethanol, a pharmacological interaction may occur, potentiating the central nervous system depression produced by either drug.
# BIO Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'ethanol', 'type': 'drug', 'start': 29, 'end': 35}]
#
# Sentence: In addition to this pharmacological interaction, this report describes a novel chemical reaction between temazepam (a benzodiazepine) and ethanol under acidic conditions similar to those found in vivo, resulting in a 3-ethoxylated product.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'temazepam', 'type': 'drug', 'start': 105, 'end': 113}, {'text': 'benzodiazepine', 'type': 'group', 'start': 118, 'end': 131}, {'text': 'ethanol', 'type': 'drug', 'start': 138, 'end': 144}]
#
# Sentence: Optimal conditions, kinetics, equilibrium, and the mechanism of this acid-catalyzed ethanolysis are reported.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: []
#
# Sentence: The results raise the possibility that the ethanolysis reaction may occur in the stomach of people who consume alcohol and 3-hydroxy-1,4-benzodiazepine on a regular basis.
# BIO Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'alcohol', 'type': 'drug', 'start': 111, 'end': 117}, {'text': '3-hydroxy-1,4-benzodiazepine', 'type': 'group', 'start': 123, 'end': 150}]
#
# Sentence: The acid-catalyzed ethanol-drug reaction is a relatively unexplored area and may alter the pharmacological action of some drugs.
# BIO Tags: ['O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Entities: [{'text': 'ethanol', 'type': 'drug', 'start': 19, 'end': 25}]

# %% [markdown]
# ### **Groq Console**

# %%
import time
from groq import Groq

# %%
# Function to make a request with rate-limiting
def make_request(sentence):
    client = Groq(
    api_key='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',
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": """ 
                You are a specialized AI model trained to identify
                and extract drug-related entities from text. Your goal is to accurately 
                recognize and classify entities such as drug names, drug categories, and 
                related medical terminology. Always output your response in the requested 
                structured format. If no relevant entities are found, respond with 'No entities found'.
                """
            },
            {
                "role": "user",
                "content": f"""
                Your task is to extract drug names from the given text. Only include valid drug names explicitly mentioned in the text. Provide the list of drug names as shown.

                Example 1:
                Input: 'Ketoconazole/Itraconazole, Macrolides, Including Erythromycin.'
                Output: ["Ketoconazole/Itraconazole","Macrolides", "Erythromycin"]

                Example 2:
                Input: 'Methotrexate: HUMIRA has been studied in rheumatoid arthritis patients taking concomitant MTX.'
                Output: ["Methotrexate", "HUMIRA", "MTX"]

                Now process the following text:
                {sentence}
                 """,
            }
        ],
        model="llama-3.3-70b-versatile",
        stream=False,
    )
    print(chat_completion.choices[0].message.content)
    return chat_completion.choices[0].message.content

# Rate-limit loop
requests_per_minute = 15
interval = 60 / requests_per_minute


all_results_generated = []
for result in train_results[:100]:
    entities_present = []
    drugs = make_request(result['sentence'])
    if drugs == 'No entities found':
        drugs = []
    else:
        drugs = json.loads(drugs)
    print(f"Sentence: {result['sentence']}")
    print(f"BIO_Tags: {result['tags']}")
    for entity in result['entity']:
        entities_present.append(entity['text'])
    print(entities_present)
    print(f"Extracted Drugs: {drugs}")
    all_results_generated.append({
        'sentence': result['sentence'],
        'tags' : result['tags'],
        'drugs_present': entities_present,
        'extracted_drugs': drugs,
    })
    time.sleep(interval)  # Wait to maintain the rate limit
# Out:
# No entities found
# Sentence: No drug, nutritional supplement, food or herb interactions have yet been reported.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["Plenaxis"]
# Sentence: No formal drug/drug interaction studies with Plenaxis were performed.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# ["Plenaxis"]
# Sentence: Cytochrome P-450 is not known to be involved in the metabolism of Plenaxis.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# ["Plenaxis"]
# Sentence: Plenaxis is highly bound to plasma proteins (96 to 99%).
# BIO_Tags: ['B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# ["Plenaxis", "testosterone"]
# Sentence: Laboratory Tests Response to Plenaxis should be monitored by measuring serum total testosterone concentrations just prior to administration on Day 29 and every 8 weeks thereafter.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Plenaxis', 'testosterone']
# Extracted Drugs: ['Plenaxis', 'testosterone']
# ["Plenaxis"]
# Sentence: Serum transaminase levels should be obtained before starting treatment with Plenaxis and periodically during treatment.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# No entities found
# Sentence: Periodic measurement of serum PSA levels may also be considered.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["ORENCIA"]
# Sentence: Formal drug interaction studies have not been conducted with ORENCIA.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['ORENCIA']
# Extracted Drugs: ['ORENCIA']
# ["MTX", "NSAIDs", "corticosteroids", "abatacept", "TNF blocking agents"]
# Sentence: Population pharmacokinetic analyses revealed that MTX, NSAIDs, corticosteroids, and TNF blocking agents did not influence abatacept clearance.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'B-group', 'B-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'B-drug', 'O']
# ['MTX', 'NSAIDs', 'corticosteroids', 'TNF blocking agents', 'abatacept']
# Extracted Drugs: ['MTX', 'NSAIDs', 'corticosteroids', 'abatacept', 'TNF blocking agents']
# ["ORENCIA", "MTX", "NSAIDs", "azathioprine", "chloroquine", "gold", "hydroxychloroquine", "leflunomide", "sulfasalazine", "anakinra"]
# Sentence: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, hydroxychloroquine, leflunomide, sulfasalazine, and anakinra.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'B-drug', 'B-group', 'B-group', 'B-group', 'I-group', 'I-group', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-drug']
# ['ORENCIA', 'MTX', 'NSAIDs', 'corticosteroids', 'TNF blocking agents', 'azathioprine', 'chloroquine', 'gold', 'hydroxychloroquine', 'leflunomide', 'sulfasalazine', 'anakinra']
# Extracted Drugs: ['ORENCIA', 'MTX', 'NSAIDs', 'azathioprine', 'chloroquine', 'gold', 'hydroxychloroquine', 'leflunomide', 'sulfasalazine', 'anakinra']
# ["ORENCIA", "TNF antagonist"]
# Sentence: Concurrent administration of a TNF antagonist with ORENCIA has been associated with an increased risk of serious infections and no significant additional efficacy over use of the TNF antagonists alone.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O']
# ['TNF antagonist', 'ORENCIA', 'TNF antagonists']
# Extracted Drugs: ['ORENCIA', 'TNF antagonist']
# ["ORENCIA", "TNF antagonists"]
# Sentence: Concurrent therapy with ORENCIA and TNF antagonists is not recommended.
# BIO_Tags: ['O', 'O', 'O', 'B-brand', 'O', 'B-group', 'I-group', 'O', 'O', 'O']
# ['ORENCIA', 'TNF antagonists']
# Extracted Drugs: ['ORENCIA', 'TNF antagonists']
# ["ORENCIA", "anakinra"]
# Sentence: There is insufficient experience to assess the safety and efficacy of ORENCIA administered concurrently with anakinra, and therefore such use is not recommended.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['ORENCIA', 'anakinra']
# Extracted Drugs: ['ORENCIA', 'anakinra']
# ["Abciximab"]
# Sentence: Formal drug interaction studies with Abciximab have not been conducted.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O']
# ['Abciximab']
# Extracted Drugs: ['Abciximab']
# ["Abciximab"]
# Sentence: Abciximab has been administered to patients with ischemic heart disease treated concomitantly with a broad range of medications used in the treatment of angina myocardial infarction and hypertension.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Abciximab']
# Extracted Drugs: ['Abciximab']
# ["heparin", "warfarin", "ticlopidine", "aspirin"]
# Sentence: These medications have included heparin, warfarin, beta-adrenergic receptor blockers, calcium channel antagonists, angiotensin converting enzyme inhibitors, intravenous and oral nitrates, ticlopidine, and aspirin.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'B-group', 'B-drug', 'O', 'B-brand']
# ['heparin', 'warfarin', 'beta-adrenergic receptor blockers', 'calcium channel antagonists', 'angiotensin converting enzyme inhibitors', 'nitrates', 'ticlopidine', 'aspirin']
# Extracted Drugs: ['heparin', 'warfarin', 'ticlopidine', 'aspirin']
# ["Heparin", "anticoagulants", "thrombolytics", "anti platelet agents"]
# Sentence: Heparin, other anticoagulants, thrombolytics, and anti platelet agents are associated with an increase in bleeding.
# BIO_Tags: ['B-drug', 'O', 'B-group', 'B-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Heparin', 'anticoagulants', 'thrombolytics', 'anti platelet agents']
# Extracted Drugs: ['Heparin', 'anticoagulants', 'thrombolytics', 'anti platelet agents']
# No entities found
# Sentence: Patients with HACA titers may have allergic or hypersensitivity reactions when treated with other diagnostic or therapeutic monoclonal antibodies.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'B-group', 'B-group', 'I-group']
# ['diagnostic monoclonal antibodies', 'diagnostic monoclonal antibodies', 'therapeutic monoclonal antibodies']
# Extracted Drugs: []
# ["Acamprosate", "alcohol"]
# Sentence: The concomitant intake of alcohol and Acamprosate does not affect the pharmacokinetics of either alcohol or acamprosate.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# ['alcohol', 'Acamprosate', 'alcohol', 'acamprosate']
# Extracted Drugs: ['Acamprosate', 'alcohol']
# ["Disulfiram", "Diazepam", "Acamprosate"]
# Sentence: Pharmacokinetic studies indicate that administration of disulfiram or diazepam does not affect the pharmacokinetics of acamprosate.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['disulfiram', 'diazepam', 'acamprosate']
# Extracted Drugs: ['Disulfiram', 'Diazepam', 'Acamprosate']
# ["naltrexone", "Acamprosate"]
# Sentence: Co-administration of naltrexone with Acamprosate produced a 25% increase in AUC and a 33% increase in the Cmax of acamprosate.
# BIO_Tags: ['O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['naltrexone', 'Acamprosate', 'acamprosate']
# Extracted Drugs: ['naltrexone', 'Acamprosate']
# No entities found
# Sentence: No adjustment of dosage is recommended in such patients.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["naltrexone", "6-beta-naltrexol", "Acamprosate"]
# Sentence: The pharmacokinetics of naltrexone and its major metabolite 6-beta-naltrexol were unaffected following co-administration with Acamprosate.
# BIO_Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug_n', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['naltrexone', '6-beta-naltrexol', 'Acamprosate']
# Extracted Drugs: ['naltrexone', '6-beta-naltrexol', 'Acamprosate']
# ["Acamprosate", "benzodiazepines"]
# Sentence: Other concomitant therapies: In clinical trials, the safety profile in subjects treated with Acamprosate concomitantly with anxiolytics, hypnotics and sedatives (including benzodiazepines), or non-opioid analgesics was similar to that of subjects taking placebo with these concomitant medications.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'B-group', 'B-group', 'O', 'B-group', 'O', 'B-group', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acamprosate', 'anxiolytics', 'hypnotics', 'sedatives', 'benzodiazepines', 'non-opioid analgesics']
# Extracted Drugs: ['Acamprosate', 'benzodiazepines']
# ["Acamprosate", "antidepressants"]
# Sentence: Patients taking Acamprosate concomitantly with antidepressants more commonly reported both weight gain and weight loss, compared with patients taking either medication alone.
# BIO_Tags: ['O', 'O', 'B-drug', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acamprosate', 'antidepressants']
# Extracted Drugs: ['Acamprosate', 'antidepressants']
# No entities found
# Sentence: Certain drugs tend to produce hyperglycemia and may lead to loss of blood glucose control.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["thiazides", "corticosteroids", "phenothiazines", "thyroid products", "estrogens", "oral contraceptives", "phenytoin", "nicotinic acid", "sympathomimetics", "calcium channel-blocking drugs", "isoniazid"]
# Sentence: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'B-group', 'B-group', 'B-group', 'B-group', 'I-group', 'B-group', 'O', 'B-group', 'B-drug', 'B-drug', 'I-drug', 'B-group', 'B-group', 'I-group', 'I-group', 'O', 'B-drug']
# ['thiazides', 'diuretics', 'corticosteroids', 'phenothiazines', 'thyroid products', 'estrogens', 'contraceptives', 'phenytoin', 'nicotinic acid', 'sympathomimetics', 'calcium channel-blocking drugs', 'isoniazid']
# Extracted Drugs: ['thiazides', 'corticosteroids', 'phenothiazines', 'thyroid products', 'estrogens', 'oral contraceptives', 'phenytoin', 'nicotinic acid', 'sympathomimetics', 'calcium channel-blocking drugs', 'isoniazid']
# ["Acarbose"]
# Sentence: When such drugs are administered to a patient receiving Acarbose, the patient should be closely observed for loss of blood glucose control.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acarbose']
# Extracted Drugs: ['Acarbose']
# ["Acarbose", "sulfonylureas", "insulin"]
# Sentence: When such drugs are withdrawn from patients receiving Acarbose in combination with sulfonylureas or insulin, patients should be observed closely for any evidence of hypoglycemia.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acarbose', 'sulfonylureas', 'insulin']
# Extracted Drugs: ['Acarbose', 'sulfonylureas', 'insulin']
# ["Acarbose", "charcoal", "amylase", "pancreatin"]
# Sentence: Intestinal adsorbents (e. g., charcoal) and digestive enzyme preparations containing carbohydrate-splitting enzymes (e. g., amylase, pancreatin) may reduce the effect of Acarbose and should not be taken concomitantly.
# BIO_Tags: ['B-group', 'I-group', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Intestinal adsorbents', 'charcoal', 'digestive enzyme preparations', 'amylase', 'pancreatin', 'Acarbose']
# Extracted Drugs: ['Acarbose', 'charcoal', 'amylase', 'pancreatin']
# ["Acarbose", "Digoxin"]
# Sentence: Acarbose has been shown to change the bioavailabillty digoxin when they are co-administered, which may require digoxin dose adjustment.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O']
# ['Acarbose', 'digoxin', 'digoxin']
# Extracted Drugs: ['Acarbose', 'Digoxin']
# ["Acarbose", "Digoxin", "Nifedipine", "Propranolol", "Ranitidine"]
# Sentence: Studies in healthy volunteers have shown that Acarbose has no effect on either the pharmacokinetics or pharmacodynamics of digoxin, nifedipine, propranolol, or ranitidine.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-drug']
# ['Acarbose', 'digoxin', 'nifedipine', 'propranolol', 'ranitidine']
# Extracted Drugs: ['Acarbose', 'Digoxin', 'Nifedipine', 'Propranolol', 'Ranitidine']
# ["Acarbose", "Glyburide"]
# Sentence: Acarbose did not interfere with the absorption or disposition of the sulfonylurea glyburide in diabetic patients.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'O', 'O']
# ['Acarbose', 'sulfonylurea', 'glyburide']
# Extracted Drugs: ['Acarbose', 'Glyburide']
# ["Acarbose", "Digoxin"]
# Sentence: Acarbose may affect digoxin bioavailabillty and may require dose adjustment of digoxin by 16% (90% confidence interval: 8-23%), decrease mean C max digoxin by 26% (90% confidence interval: 16-34%) and decrease mean trough concentrations of digoxin by 9% (90% confidence limit: 19% decrease to 2% increase).
# BIO_Tags: ['B-drug', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acarbose', 'digoxin', 'digoxin', 'digoxin', 'digoxin']
# Extracted Drugs: ['Acarbose', 'Digoxin']
# ["metformin", "Acarbose"]
# Sentence: The amount of metformin absorbed while taking Acarbose was bioequivalent to the amount absorbed when taking placebo, as indicated by the plasma AUC values.
# BIO_Tags: ['O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['metformin', 'Acarbose']
# Extracted Drugs: ['metformin', 'Acarbose']
# ["metformin", "Acarbose"]
# Sentence: However, the peak plasma level of metformin was reduced by approximately 20% when taking Acarbose due to a slight delay in the absorption of metformin.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['metformin', 'Acarbose', 'metformin']
# Extracted Drugs: ['metformin', 'Acarbose']
# ["Acarbose", "Metformin"]
# Sentence: There is little if any clinically significant interaction between Acarbose and metformin.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# ['Acarbose', 'metformin']
# Extracted Drugs: ['Acarbose', 'Metformin']
# ["reserpine"]
# Sentence: Catecholamine-depleting drugs, such as reserpine, may have an additive effect when given with beta-blocking agents.
# BIO_Tags: ['B-group', 'I-group', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group']
# ['Catecholamine-depleting drugs', 'reserpine', 'beta-blocking agents']
# Extracted Drugs: ['reserpine']
# ["acebutolol", "catecholamine"]
# Sentence: Patients treated with acebutolol plus catecholamine depletors should, therefore, be observed closely for evidence of marked bradycardia or hypotension which may present as vertigo, syncope/presyncope, or orthostatic changes in blood pressure without compensatory tachycardia.
# BIO_Tags: ['O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['acebutolol', 'catecholamine depletors']
# Extracted Drugs: ['acebutolol', 'catecholamine']
# ["beta-adrenergic antagonists", "alpha-adrenergic stimulants"]
# Sentence: Exaggerated hypertensive responses have been reported from the combined use of beta-adrenergic antagonists and alpha-adrenergic stimulants, including those contained in proprietary cold remedies and vasoconstrictive nasal drops.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['beta-adrenergic antagonists', 'alpha-adrenergic stimulants']
# Extracted Drugs: ['beta-adrenergic antagonists', 'alpha-adrenergic stimulants']
# ["beta-blockers"]
# Sentence: Patients receiving beta-blockers should be warned of this potential hazard.
# BIO_Tags: ['O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['beta-blockers']
# Extracted Drugs: ['beta-blockers']
# ["beta-adrenoceptor blocking agents", "nonsteroidal anti-inflammatory drugs"]
# Sentence: Blunting of the antihypertensive effect of beta-adrenoceptor blocking agents by nonsteroidal anti-inflammatory drugs has been reported.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O']
# ['beta-adrenoceptor blocking agents', 'nonsteroidal anti-inflammatory drugs']
# Extracted Drugs: ['beta-adrenoceptor blocking agents', 'nonsteroidal anti-inflammatory drugs']
# ["digoxin", "hydrochlorothiazide", "hydralazine", "sulfinpyrazone", "oral contraceptives", "tolbutamide", "warfarin"]
# Sentence: No significant interactions with digoxin, hydrochlorothiazide, hydralazine, sulfinpyrazone, oral contraceptives, tolbutamide, or warfarin have been observed.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'B-drug', 'B-drug', 'O', 'B-group', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# ['digoxin', 'hydrochlorothiazide', 'hydralazine', 'sulfinpyrazone', 'contraceptives', 'tolbutamide', 'warfarin']
# Extracted Drugs: ['digoxin', 'hydrochlorothiazide', 'hydralazine', 'sulfinpyrazone', 'oral contraceptives', 'tolbutamide', 'warfarin']
# ["DIAMOX", "phenytoin"]
# Sentence: DIAMOX modifies phenytoin metabolism with increased serum levels of phenytoin.
# BIO_Tags: ['B-brand', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['DIAMOX', 'phenytoin', 'phenytoin']
# Extracted Drugs: ['DIAMOX', 'phenytoin']
# ["phenytoin"]
# Sentence: This may increase or enhance the occurrence of osteomalacia in some patients receiving chronic phenytoin therapy.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# ['phenytoin']
# Extracted Drugs: ['phenytoin']
# No entities found
# Sentence: Caution is advised in patients receiving chronic concomitant therapy.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["DIAMOX", "primidone"]
# Sentence: By decreasing the gastrointestinal absorption of primidone, DIAMOX may decrease serum concentrations of primidone and its metabolites, with a consequent possible decrease in anticonvulsant effect.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['primidone', 'DIAMOX', 'primidone']
# Extracted Drugs: ['DIAMOX', 'primidone']
# ["DIAMOX", "primidone"]
# Sentence: Caution is advised when beginning, discontinuing, or changing the dose of DIAMOX in patients receiving primidone.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-drug']
# ['DIAMOX', 'primidone']
# Extracted Drugs: ['DIAMOX', 'primidone']
# No entities found
# Sentence: Because of possible additive effects with other carbonic anhydrase inhibitors, concomitant use is not advisable.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O']
# ['carbonic anhydrase inhibitors']
# Extracted Drugs: []
# ["Acetazolamide", "folic acid"]
# Sentence: Acetazolamide may increase the effects of other folic acid antagonists.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group']
# ['Acetazolamide', 'folic acid antagonists']
# Extracted Drugs: ['Acetazolamide', 'folic acid']
# ["Acetazolamide"]
# Sentence: Acetazolamide may increase or decrease blood glucose levels.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acetazolamide']
# Extracted Drugs: ['Acetazolamide']
# ["antidiabetic agents"]
# Sentence: Consideration should be taken in patients being treated with antidiabetic agents.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# ['antidiabetic']
# Extracted Drugs: ['antidiabetic agents']
# ["Acetazolamide", "amphetamine"]
# Sentence: Acetazolamide decreases urinary excretion of amphetamine and may enhance the magnitude and duration of their effect.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acetazolamide', 'amphetamine']
# Extracted Drugs: ['Acetazolamide', 'amphetamine']
# ["Acetazolamide", "quinidine"]
# Sentence: Acetazolamide reduces urinary excretion of quinidine and may enhance its effect.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O']
# ['Acetazolamide', 'quinidine']
# Extracted Drugs: ['Acetazolamide', 'quinidine']
# ["Acetazolamide", "Methenamine"]
# Sentence: Acetazolamide may prevent the urinary antiseptic effect of methenamine.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['Acetazolamide', 'methenamine']
# Extracted Drugs: ['Acetazolamide', 'Methenamine']
# ["Acetazolamide", "Lithium"]
# Sentence: Acetazolamide increases lithium excretion and the lithium may be decreased.
# BIO_Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# ['Acetazolamide', 'lithium', 'lithium']
# Extracted Drugs: ['Acetazolamide', 'Lithium']
# ["Acetazolamide", "sodium bicarbonate"]
# Sentence: Acetazolamide and sodium bicarbonate used concurrently increases the risk of renal calculus formation.
# BIO_Tags: ['B-drug', 'O', 'B-drug', 'I-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Acetazolamide', 'sodium bicarbonate']
# Extracted Drugs: ['Acetazolamide', 'sodium bicarbonate']
# ["Acetazolamide", "Cyclosporine"]
# Sentence: Acetazolamide may elevate cyclosporine levels.
# BIO_Tags: ['B-drug', 'O', 'O', 'B-drug', 'O']
# ['Acetazolamide', 'cyclosporine']
# Extracted Drugs: ['Acetazolamide', 'Cyclosporine']
# No entities found
# Sentence: Concomitant use with iron                    supplements may result in the reduced absorption of iron.
# BIO_Tags: ['O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['iron supplement', 'iron']
# Extracted Drugs: []
# ["probenecid", "acyclovir"]
# Sentence: Co-administration of probenecid with acyclovir has been shown to increase the mean half-life and the area under the concentration-time curve.
# BIO_Tags: ['O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['probenecid', 'acyclovir']
# Extracted Drugs: ['probenecid', 'acyclovir']
# No entities found
# Sentence: Urinary excretion and renal clearance were correspondingly reduced.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# No entities found
# Sentence: The clinical effects of this combination have not been studied.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["Ethanol", "Etretinate", "Acitretin"]
# Sentence: Ethanol:Clinical evidence has shown that etretinate can be formed with concurrent ingestion of acitretin and ethanol.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# ['Ethanol', 'etretinate', 'acitretin', 'ethanol']
# Extracted Drugs: ['Ethanol', 'Etretinate', 'Acitretin']
# ["Glibenclamide", "Acitretin", "Chlorpropamide"]
# Sentence: Glibenclamide: In a study of 7 healthy male volunteers, acitretin treatment potentiated the blood glucose lowering effect of glibenclamide (a sulfonylurea similar to chlorpropamide) in 3 of the 7 subjects.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Glibenclamide', 'acitretin', 'glibenclamide', 'sulfonylurea', 'chlorpropamide']
# Extracted Drugs: ['Glibenclamide', 'Acitretin', 'Chlorpropamide']
# ["Glibenclamide", "Acitretin"]
# Sentence: Repeating the study with 6 healthy male volunteers in the absence of glibenclamide did not detect an effect of acitretin on glucose tolerance.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# ['glibenclamide', 'acitretin']
# Extracted Drugs: ['Glibenclamide', 'Acitretin']
# ["Soriatane"]
# Sentence: Careful supervision of diabetic patients under treatment with Soriatane is recommended.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# ['Soriatane']
# Extracted Drugs: ['Soriatane']
# ["acitretin"]
# Sentence: Hormonal Contraceptives: It has not been established if there is a pharmacokinetic interaction between acitretin and combined oral contraceptives.
# BIO_Tags: ['B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'I-group']
# ['Hormonal Contraceptives', 'acitretin', 'combined oral contraceptives']
# Extracted Drugs: ['acitretin']
# ["acitretin", "progestin"]
# Sentence: However, it has been established that acitretin interferes with the contraceptive effect of microdosed progestin minipill preparations.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O']
# ['acitretin', 'progestin']
# Extracted Drugs: ['acitretin', 'progestin']
# ["Soriatane", "minipill"]
# Sentence: Microdosed minipill progestin preparations are not recommended for use with Soriatane.
# BIO_Tags: ['O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['progestin', 'Soriatane']
# Extracted Drugs: ['Soriatane', 'minipill']
# ["acitretin"]
# Sentence: It is not known whether other progestational contraceptives, such as implants and injectables, are adequate methods of contraception during acitretin therapy.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O']
# ['progestational contraceptives', 'acitretin']
# Extracted Drugs: ['acitretin']
# ["Methotrexate", "Etretinate"]
# Sentence: Methotrexate: An increased risk of hepatitis has been reported to result from combined use of methotrexate and etretinate.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug']
# ['Methotrexate', 'methotrexate', 'etretinate']
# Extracted Drugs: ['Methotrexate', 'Etretinate']
# ["methotrexate", "acitretin"]
# Sentence: Consequently, the combination of methotrexate with acitretin is also contraindicated.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'O', 'O', 'O']
# ['methotrexate', 'acitretin']
# Extracted Drugs: ['methotrexate', 'acitretin']
# ["Phenytoin", "Acitretin"]
# Sentence: Phenytoin: If acitretin is given concurrently with phenytoin, the protein binding of phenytoin may be reduced.
# BIO_Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O']
# ['Phenytoin', 'acitretin', 'phenytoin', 'phenytoin']
# Extracted Drugs: ['Phenytoin', 'Acitretin']
# ["acitretin", "tetracyclines"]
# Sentence: Tetracyclines: Since both acitretin and tetracyclines can cause increased intracranial pressure, their combined use is contraindicated.
# BIO_Tags: ['B-group', 'O', 'O', 'B-drug', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Tetracyclines', 'acitretin', 'tetracyclines']
# Extracted Drugs: ['acitretin', 'tetracyclines']
# ["Vitamin A", "acitretin"]
# Sentence: Vitamin A and oral retinoids: Concomitant administration of vitamin A and/or other oral retinoids with acitretin must be avoided because of the risk of hypervitaminosis A.
# BIO_Tags: ['B-group', 'I-group', 'O', 'O', 'B-group', 'O', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Vitamin A', 'retinoids', 'vitamin A', 'retinoids', 'acitretin']
# Extracted Drugs: ['Vitamin A', 'acitretin']
# ["acitretin", "cimetidine", "digoxin", "glyburide"]
# Sentence: Other: There appears to be no pharmacokinetic interaction between acitretin and cimetidine, digoxin, or glyburide.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'B-drug', 'B-drug', 'O', 'B-drug']
# ['acitretin', 'cimetidine', 'digoxin', 'glyburide']
# Extracted Drugs: ['acitretin', 'cimetidine', 'digoxin', 'glyburide']
# ["acitretin", "warfarin"]
# Sentence: Investigations into the effect of acitretin on the protein binding of anticoagulants of the coumarin type (warfarin) revealed no interaction.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'B-group', 'I-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O']
# ['acitretin', 'anticoagulants of the coumarin type', 'warfarin']
# Extracted Drugs: ['acitretin', 'warfarin']
# No entities found
# Sentence: Laboratory Tests If significant abnormal laboratory results are obtained, either dosage reduction with careful monitoring or treatment discontinuation is recommended, depending on clinical judgement.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["retinoids"]
# Sentence: Blood Sugar: Some patients receiving retinoids have experienced problems with blood sugar control.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['retinoids']
# Extracted Drugs: ['retinoids']
# ["retinoid"]
# Sentence: In addition, new cases of diabetes have been diagnosed during retinoid therapy, including diabetic ketoacidosis.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O']
# ['retinoid']
# Extracted Drugs: ['retinoid']
# No entities found
# Sentence: In diabetics, blood-sugar levels should be monitored very carefully.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# No entities found
# Sentence: Lipids: In clinical studies, the incidence of hypertriglyceridemia was 66%, hypercholesterolemia was 33% and that of decreased HDL was 40%.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# No entities found
# Sentence: Pretreatment and follow-up measurements should be obtained under fasting conditions.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["Soriatane"]
# Sentence: It is recommended that these tests be performed weekly or every other week until the lipid response to Soriatane has stabilized.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# ['Soriatane']
# Extracted Drugs: ['Soriatane']
# ["Soriatane", "AST", "ALT", "LDH"]
# Sentence: Liver Function Tests: Elevations of AST (SGOT), ALT (SGPT) or LDH were experienced by approximately 1 in 3 patients treated with Soriatane.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['Soriatane']
# Extracted Drugs: ['Soriatane', 'AST', 'ALT', 'LDH']
# ["Soriatane"]
# Sentence: It is recommended that these tests be performed prior to initiation of Soriatane therapy, at 1- to 2-week intervals until stable and thereafter at intervals as clinically indicated.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Soriatane']
# Extracted Drugs: ['Soriatane']
# ["Methotrexate", "HUMIRA", "MTX"]
# Sentence: Methotrexate: HUMIRA has been studied in rheumatoid arthritis patients taking concomitant MTX.
# BIO_Tags: ['B-drug', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug']
# ['Methotrexate', 'HUMIRA', 'MTX']
# Extracted Drugs: ['Methotrexate', 'HUMIRA', 'MTX']
# ["HUMIRA", "MTX"]
# Sentence: The data do not suggest the need for dose adjustment of either HUMIRA or MTX.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'B-drug']
# ['HUMIRA', 'MTX']
# Extracted Drugs: ['HUMIRA', 'MTX']
# ["Anakinra"]
# Sentence: Anakinra: Concurrent administration of anakinra (an interleukin-1 antagonist) and another TNF-blocking agent has been associated with an increased risk of serious infections, an increased risk of neutropenia and no additional benefit compared to these medicinal products alone.
# BIO_Tags: ['B-drug', 'O', 'O', 'O', 'B-drug', 'O', 'B-group', 'I-group', 'O', 'O', 'B-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Anakinra', 'anakinra', 'interleukin-1 antagonist', 'TNF-blocking agent']
# Extracted Drugs: ['Anakinra']
# ["anakinra", "HUMIRA"]
# Sentence: The safety and efficacy of anakinra used in combination with HUMIRA has not been studied.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O']
# ['anakinra', 'HUMIRA']
# Extracted Drugs: ['anakinra', 'HUMIRA']
# ["Anakinra", "HUMIRA"]
# Sentence: Therefore the, combination of anakinra with other TNF-blocking agents, including HUMIRA, may also result i n similar toxicities.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'B-group', 'I-group', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['anakinra', 'TNF-blocking agents', 'HUMIRA']
# Extracted Drugs: ['Anakinra', 'HUMIRA']
# ["DIFFERIN"]
# Sentence: As DIFFERIN Gel has the potential to produce local irritation in some patients, concomitant use of other potentially irritating topical products (medicated or abrasive soaps and cleansers, soaps and cosmetics that have a strong drying effect, and products with high concentrations of alcohol, astringents, spices or lime) should be approached with caution.
# BIO_Tags: ['O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['DIFFERIN']
# Extracted Drugs: ['DIFFERIN']
# ["sulfur", "resorcinol", "salicylic acid", "DIFFERIN"]
# Sentence: Particular caution should be exercised in using preparations containing sulfur, resorcinol, or salicylic acid in combination with DIFFERIN Gel.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-drug', 'O', 'B-drug', 'I-drug', 'O', 'O', 'O', 'B-brand', 'O']
# ['sulfur', 'resorcinol', 'salicylic acid', 'DIFFERIN']
# Extracted Drugs: ['sulfur', 'resorcinol', 'salicylic acid', 'DIFFERIN']
# ["DIFFERIN"]
# Sentence: If these preparations have been used it is advisable not to start therapy with DIFFERIN Gel until the effects of such preparations in the skin have subsided.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['DIFFERIN']
# Extracted Drugs: ['DIFFERIN']
# ["aminoglycosides", "gentamicin", "amikacin", "amphotericin B", "cyclosporine", "non-steroidal anti-inflammatory drugs", "ibuprofen", "tacrolimus", "vancomycin"]
# Sentence: Before using this medication, tell your doctor or pharmacist of all prescription and nonprescription products you may use, especially of: aminoglycosides (e.g., gentamicin, amikacin), amphotericin B, cyclosporine, non-steroidal anti-inflammatory drugs (e.g., ibuprofen), tacrolimus, vancomycin.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-group', 'O', 'B-drug', 'B-drug', 'B-drug', 'I-drug', 'B-drug', 'B-group', 'I-group', 'O', 'O', 'B-drug', 'B-drug', 'B-drug']
# ['aminoglycosides', 'gentamicin', 'amikacin', 'amphotericin B', 'cyclosporine', 'non-steroidal anti-inflammatory', 'ibuprofen', 'tacrolimus', 'vancomycin']
# Extracted Drugs: ['aminoglycosides', 'gentamicin', 'amikacin', 'amphotericin B', 'cyclosporine', 'non-steroidal anti-inflammatory drugs', 'ibuprofen', 'tacrolimus', 'vancomycin']
# No entities found
# Sentence: Do not start or stop any medicine without doctor or pharmacist approval.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# ["Adenocard", "adenosine", "quinidine"]
# Sentence: Intravenous Adenocard (adenosine) has been effectively administered in the presence of other cardioactive drugs, such as quinidine, beta-adrenergic blocking agents, calcium channel blocking agents, and angiotensin converting enzyme inhibitors, without any change in the adverse reaction profile.
# BIO_Tags: ['O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'B-group', 'I-group', 'I-group', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'B-group', 'I-group', 'I-group', 'I-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Adenocard', 'adenosine', 'quinidine', 'beta-adrenergic blocking agents', 'calcium channel blocking agents', 'angiotensin converting enzyme inhibitors']
# Extracted Drugs: ['Adenocard', 'adenosine', 'quinidine']
# ["Digoxin", "Verapamil", "Adenocard"]
# Sentence: Digoxin and verapamil use may be rarely associated with ventricular fibrillation when combined with Adenocard.
# BIO_Tags: ['B-drug', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['Digoxin', 'verapamil', 'Adenocard']
# Extracted Drugs: ['Digoxin', 'Verapamil', 'Adenocard']
# ["Adenocard"]
# Sentence: Because of the potential for additive or synergistic depressant effects on the SA and AV nodes, however, Adenocard should be used with caution in the presence of these agents.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Adenocard']
# Extracted Drugs: ['Adenocard']
# ["Adenocard", "digitalis"]
# Sentence: The use of Adenocard in patients receiving digitalis may be rarely associated with ventricular fibrillation.
# BIO_Tags: ['O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'B-group', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Adenocard', 'digitalis']
# Extracted Drugs: ['Adenocard', 'digitalis']

# %% [markdown]
# Arrange Drugs Present and Extracted Drugs in a dataframe

# %%
df = pd.DataFrame(all_results_generated)

# Convert the drug present to lower case and set 
# it as a set to remove duplicates
df['drugs_present'] = df['drugs_present'].apply(lambda x: set([drug.lower() for drug in x]))
df['extracted_drugs'] = df['extracted_drugs'].apply(lambda x: set([drug.lower() for drug in x]))

# df['drugs_present'] = df['drugs_present'].apply(lambda x: ', '.join(x))
# df['extracted_drugs'] = df['extracted_drugs'].apply(lambda x: ', '.join(x))
df['correct'] = df['drugs_present'] == df['extracted_drugs']
df
# Out:
#                                              sentence  \
# 0   No drug, nutritional supplement, food or herb ...
# 1   No formal drug/drug interaction studies with P...
# 2   Cytochrome P-450 is not known to be involved i...
# 3   Plenaxis is highly bound to plasma proteins (9...
# 4   Laboratory Tests Response to Plenaxis should b...
# ..                                                ...
# 95  Do not start or stop any medicine without doct...
# 96  Intravenous Adenocard (adenosine) has been eff...
# 97  Digoxin and verapamil use may be rarely associ...
# 98  Because of the potential for additive or syner...
# 99  The use of Adenocard in patients receiving dig...
#
#                                                  tags  \
# 0                [O, O, O, O, O, O, O, O, O, O, O, O]
# 1                   [O, O, O, O, O, O, B-brand, O, O]
# 2       [O, O, O, O, O, O, O, O, O, O, O, O, B-brand]
# 3                [B-brand, O, O, O, O, O, O, O, O, O]
# 4   [O, O, O, O, B-brand, O, O, O, O, O, O, O, B-d...
# ..                                                ...
# 95               [O, O, O, O, O, O, O, O, O, O, O, O]
# 96  [O, B-brand, O, O, O, O, O, O, O, O, O, O, O, ...
# 97  [B-drug, O, B-drug, O, O, O, O, O, O, O, O, O,...
# 98  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 99  [O, O, O, B-brand, O, O, O, B-group, O, O, O, ...
#
#                                         drugs_present  \
# 0                                                  {}
# 1                                          {plenaxis}
# 2                                          {plenaxis}
# 3                                          {plenaxis}
# 4                            {plenaxis, testosterone}
# ..                                                ...
# 95                                                 {}
# 96  {angiotensin converting enzyme inhibitors, bet...
# 97                    {verapamil, digoxin, adenocard}
# 98                                        {adenocard}
# 99                             {digitalis, adenocard}
#
#                       extracted_drugs  correct
# 0                                  {}     True
# 1                          {plenaxis}     True
# 2                          {plenaxis}     True
# 3                          {plenaxis}     True
# 4            {plenaxis, testosterone}     True
# ..                                ...      ...
# 95                                 {}     True
# 96  {quinidine, adenosine, adenocard}    False
# 97    {verapamil, digoxin, adenocard}     True
# 98                        {adenocard}     True
# 99             {digitalis, adenocard}     True
#
# [100 rows x 5 columns]

# %% [markdown]
# Save the result as a CSV file

# %%
df.to_csv('results/drug_extraction_results.csv', index=False)

# %% [markdown]
# Convert the CSV file to dataframe and calculate the accuracy

# %%
df = pd.read_csv('results/drug_extraction_results.csv')

# %%
# Calculate the accuracy
accuracy = df['correct'].mean()
print(f"Accuracy: {accuracy:.2f}")

# now we need to check the number of false positives and false negatives
# False positives: Extracted drugs that are not present in the text
# False negatives: Drugs present in the text but not extracted

df['false_positive'] = df.apply(lambda x: set(x['extracted_drugs']) if isinstance(x['extracted_drugs'], (list, set)) else set(), axis=1) - \
                        df.apply(lambda x: set(x['drugs_present']) if isinstance(x['drugs_present'], (list, set)) else set(), axis=1)

df['false_negative'] = df.apply(lambda x: set(x['drugs_present']) if isinstance(x['drugs_present'], (list, set)) else set(), axis=1) - \
                        df.apply(lambda x: set(x['extracted_drugs']) if isinstance(x['extracted_drugs'], (list, set)) else set(), axis=1)


# Calculate the total number of false positives and false negatives
total_false_positives = df['false_positive'].apply(len).sum()
total_false_negatives = df['false_negative'].apply(len).sum()

print(f"Total False Positives: {total_false_positives}")
print(f"Total False Negatives: {total_false_negatives}")

# Calculate the precision and recall
precision = (len(df) - total_false_positives) / len(df)
recall = (len(df) - total_false_negatives) / len(df)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# Calculate the F1 score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f"F1 Score: {f1_score:.2f}")
# Out:
# Accuracy: 0.74
# Total False Positives: 0
# Total False Negatives: 0
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00

# %%
df

# %% [markdown]
# ### **Gemini**

# %%
api_key = "AIzaSyAlWzliqQKSKyRW2xBM9op_fToJNyId7R0"

# The endpoint URL
url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key={api_key}"

def fetch_text(message):

    # Headers and data
  headers = {
      "Content-Type": "application/json"
  }

  data = {
      "contents": [
          {
              "parts": [
                  {
                      "text": message
                  },
              ]
          }
      ]
  }

  # Make the POST request
  response = requests.post(url, headers=headers, data=json.dumps(data))
  
  # Check the response
  if response.status_code == 200:
      
      result = response.json()["candidates"][0]['content']['parts'][0]['text']
      
      return result
  if response.status_code == 429:
    return "429"
  return []

# %%
import json

def fetch_drug_entities(sentence):
    prompt = f"""
    Your task is to extract drug names from the given text. Only include valid drug names explicitly mentioned in the text. Provide the list of drug names as shown.

    Example 1:
    Input: 'Ketoconazole/Itraconazole, Macrolides, Including Erythromycin.'
    Output: ["Ketoconazole/Itraconazole","Macrolides", "Erythromycin"]

    Example 2:
    Input: 'Methotrexate: HUMIRA has been studied in rheumatoid arthritis patients taking concomitant MTX.'
    Output: ["Methotrexate", "HUMIRA", "MTX"]

    Now process the following text:
    {sentence}
    """
    response = fetch_text(prompt)  # Use your existing fetch_text function
    try:
        # Ensure the response is valid JSON
        drug_entities = json.loads(response)
    except json.JSONDecodeError:
        print(f"Error parsing JSON response: {response}")
        drug_entities = []
    return drug_entities

all_results_generated = []
for result in train_results[:10]:
    entities_present = []
    drugs = fetch_drug_entities(result['sentence'])
    print(f"Sentence: {result['sentence']}")
    print(f"BIO_Tags: {result['tags']}")
    for entity in result['entity']:
        entities_present.append(entity['text'])
    print(entities_present)
    print(f"Extracted Drugs: {drugs}")
    all_results_generated.append({
        'sentence': result['sentence'],
        'tags' : result['tags'],
        'drugs_present': entities_present,
        'extracted_drugs': drugs,
    })
# Out:
# Sentence: No drug, nutritional supplement, food or herb interactions have yet been reported.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# Sentence: No formal drug/drug interaction studies with Plenaxis were performed.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# Sentence: Cytochrome P-450 is not known to be involved in the metabolism of Plenaxis.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# Error parsing JSON response: ```
# []
# ```
# There are no drug names explicitly mentioned in the provided text.
#
# Sentence: Plenaxis is highly bound to plasma proteins (96 to 99%).
# BIO_Tags: ['B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: []
# Sentence: Laboratory Tests Response to Plenaxis should be monitored by measuring serum total testosterone concentrations just prior to administration on Day 29 and every 8 weeks thereafter.
# BIO_Tags: ['O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-drug', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Plenaxis', 'testosterone']
# Extracted Drugs: ['Plenaxis']
# Sentence: Serum transaminase levels should be obtained before starting treatment with Plenaxis and periodically during treatment.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand', 'O', 'O', 'O', 'O']
# ['Plenaxis']
# Extracted Drugs: ['Plenaxis']
# Error parsing JSON response: ```
# []
# ```
# There are no drug names mentioned in the provided text.
#
# Sentence: Periodic measurement of serum PSA levels may also be considered.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# Extracted Drugs: []
# Sentence: Formal drug interaction studies have not been conducted with ORENCIA.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-brand']
# ['ORENCIA']
# Extracted Drugs: ['ORENCIA']
# Sentence: Population pharmacokinetic analyses revealed that MTX, NSAIDs, corticosteroids, and TNF blocking agents did not influence abatacept clearance.
# BIO_Tags: ['O', 'O', 'O', 'O', 'O', 'B-drug', 'B-group', 'B-group', 'O', 'B-group', 'I-group', 'I-group', 'O', 'O', 'O', 'B-drug', 'O']
# ['MTX', 'NSAIDs', 'corticosteroids', 'TNF blocking agents', 'abatacept']
# Extracted Drugs: ['MTX', 'NSAIDs', 'corticosteroids', 'TNF', 'abatacept']
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 30
#      28 for result in train_results[:10]:
#      29     entities_present = []
# ---> 30     drugs = fetch_drug_entities(result['sentence'])
#      31     print(f"Sentence: {result['sentence']}")
#      32     print(f"BIO_Tags: {result['tags']}")
#
# Cell In[15], line 18, in fetch_drug_entities(sentence)
#       3 def fetch_drug_entities(sentence):
#       4     prompt = f"""
#       5     Your task is to extract drug names from the given text. Only include valid drug names explicitly mentioned in the text. Provide the list of drug names as shown.
#       6
#    (...)
#      16     {sentence}
#      17     """
# ---> 18     response = fetch_text(prompt)  # Use your existing fetch_text function
#      19     try:
#      20         # Ensure the response is valid JSON
#      21         drug_entities = json.loads(response)
#
# Cell In[14], line 27, in fetch_text(message)
#      14 data = {
#      15     "contents": [
#      16         {
#    (...)
#      23     ]
#      24 }
#      26 # Make the POST request
# ---> 27 response = requests.post(url, headers=headers, data=json.dumps(data))
#      29 # Check the response
#      30 if response.status_code == 200:
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     691 try:
#     692     sock: socket.socket | ssl.SSLSocket
# --> 693     self.sock = sock = self._new_conn()
#     694     server_hostname: str = self.host
#     695     tls_in_tls = False
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
