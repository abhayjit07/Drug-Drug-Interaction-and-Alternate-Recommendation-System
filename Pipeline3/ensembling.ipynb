# %% [markdown]
# ## Import Libraries

# %%
import pickle
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from joblib import load
import pandas as pd
import os
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"

# %% [markdown]
# ## BioBert Model

# %% [markdown]
# Load the saved fine-tuned BioBERT model and tokenizer

# %%
biobert_tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
biobert_model = AutoModelForSequenceClassification.from_pretrained("./model/saved_biobert_model/")  

logistic_model = load("./model/results/svm_model.pkl")
random_forest_model = load("./model/results/xgb_model.pkl")

biobert_model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
def get_biobert_prediction(drug1, drug2, sentence, model, tokenizer, device):
    # Replace drug names with placeholders for consistency
    sentence = sentence.replace(drug1, "[Drug1]").replace(drug2, "[Drug2]")
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding="max_length", max_length=128)
    inputs = {key: val.to(device) for key, val in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    probs = torch.softmax(logits, dim=1).cpu().numpy()  # Get probability scores
    return probs[0]

# %% [markdown]
# ## Classic Model Prediction

# %%
def get_classic_model_prediction(drug1, drug2, model, vectorizer):
    # Vectorize each drug name
    drug1_vec = vectorizer.transform([drug1]).toarray()
    drug2_vec = vectorizer.transform([drug2]).toarray()
    combined_vector = list(drug1_vec[0]) + list(drug2_vec[0])  # Concatenate vectors for both drugs
    probs = model.predict_proba([combined_vector])[0]  # Get probability prediction
    return probs

# %% [markdown]
# ## Parse DDI Corpus

# %%
def parse_ddi_corpus(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    data = []

    for sentence in root.iter('sentence'):
        sent_text = sentence.attrib['text']
        entities = sentence.findall('entity')
        pairs = sentence.findall('pair')

        if len(entities) == 1:
            data.append([entities[0].attrib['text'], 'NULL', sent_text, 'False'])
        else:
            for pair in pairs:
                e1 = pair.attrib['e1']
                e2 = pair.attrib['e2']
                interaction = pair.attrib['ddi']

                e1_text = next(entity.attrib['text'] for entity in entities if entity.attrib['id'] == e1)
                e2_text = next(entity.attrib['text'] for entity in entities if entity.attrib['id'] == e2)

                data.append([e1_text, e2_text, sent_text, interaction])

    df = pd.DataFrame(data, columns=['Drug1', 'Drug2', 'Sentence', 'Interaction'])
    return df

def parse_all_ddi_files(directory_paths):
    all_data = []

    for directory_path in directory_paths:
        for root, dirs, files in os.walk(directory_path):
            for file in files:
                if file.endswith('.xml'):
                    file_path = os.path.join(root, file)
                    df = parse_ddi_corpus(file_path)
                    all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    return combined_df

# Specify the paths to both directories
directory_paths = [
    '../Dataset/DDICorpus/Train/DrugBank',
    '../Dataset/DDICorpus/Train/MedLine'
]

# Parse and combine data from both directories
df = parse_all_ddi_files(directory_paths)

# Filter out rows where 'Drug1' or 'Drug2' is 'NULL'
df = df[(df['Drug1'] != 'NULL') & (df['Drug2'] != 'NULL')]

# Define the new directory path for the test data
new_directory_paths = [
    '../Dataset/DDICorpus/Test/Test for DDI Extraction task/DrugBank',
    '../Dataset/input/ddicorpus/DDICorpus/Test/Test for DDI Extraction task/MedLine'
]

# Parse and combine data from the new directory
new_test_df = parse_all_ddi_files(new_directory_paths)

# Filter out rows where 'Drug1' or 'Drug2' is 'NULL' (if needed)
test_df = new_test_df[(new_test_df['Drug1'] != 'NULL') & (new_test_df['Drug2'] != 'NULL')]

train_df=df
# Display the first few rows of the new test set
test_df.head()
# Out:
#           Drug1                  Drug2  \
# 0  Ketoconazole            tolterodine
# 1  ketoconazole      azole antifungals
# 2  ketoconazole           itraconazole
# 3  ketoconazole             miconazole
# 4  ketoconazole  macrolide antibiotics
#
#                                             Sentence Interaction
# 0  CYP3A4 Inhibitors: Ketoconazole, an inhibitor ...        true
# 1  For patients receiving ketoconazole or other p...       false
# 2  For patients receiving ketoconazole or other p...       false
# 3  For patients receiving ketoconazole or other p...       false
# 4  For patients receiving ketoconazole or other p...       false

# %%
test_df
# Out:
#              Drug1                  Drug2  \
# 0     Ketoconazole            tolterodine
# 1     ketoconazole      azole antifungals
# 2     ketoconazole           itraconazole
# 3     ketoconazole             miconazole
# 4     ketoconazole  macrolide antibiotics
# ...            ...                    ...
# 5479      SKELAXIN           barbiturates
# 5480      SKELAXIN        CNS depressants
# 5481       alcohol           barbiturates
# 5482       alcohol        CNS depressants
# 5483  barbiturates        CNS depressants
#
#                                                Sentence Interaction
# 0     CYP3A4 Inhibitors: Ketoconazole, an inhibitor ...        true
# 1     For patients receiving ketoconazole or other p...       false
# 2     For patients receiving ketoconazole or other p...       false
# 3     For patients receiving ketoconazole or other p...       false
# 4     For patients receiving ketoconazole or other p...       false
# ...                                                 ...         ...
# 5479  SKELAXIN may enhance the effects of alcohol, b...        true
# 5480  SKELAXIN may enhance the effects of alcohol, b...        true
# 5481  SKELAXIN may enhance the effects of alcohol, b...       false
# 5482  SKELAXIN may enhance the effects of alcohol, b...       false
# 5483  SKELAXIN may enhance the effects of alcohol, b...       false
#
# [5265 rows x 4 columns]

# %% [markdown]
# ## Word2Vec Model

# %%
from gensim.models import KeyedVectors

model_path = "./model/model.bin"

# Load the model with memory mapping
model = KeyedVectors.load_word2vec_format(model_path, binary=True)

print("Model loaded successfully!")

word_vector = model['drugs']
# Out:
# Model loaded successfully!

# %%
def get_drug_embeddings(drug, model):
    drug_vectors=np.array([])
    if drug in model:

        drug_vectors = model[drug]

    else:
        pass
    return drug_vectors

# %%
def get_embeddings(drug1, drug2, expected_dim=200):
    embedding1 = get_drug_embeddings(drug1, model)  # Fetch embedding for drug1
    embedding2 = get_drug_embeddings(drug2, model)  # Fetch embedding for drug2

    # Convert to numpy array if needed
    if isinstance(embedding1, dict):
        embedding1 = np.array(list(embedding1.values()))
    if isinstance(embedding2, dict):
        embedding2 = np.array(list(embedding2.values()))

    # Ensure embeddings are valid arrays
    if embedding1 is None or embedding1.size == 0:
        embedding1 = np.zeros(expected_dim)  # Pad missing embeddings
    if embedding2 is None or embedding2.size == 0:
        embedding2 = np.zeros(expected_dim)

    # Ensure embeddings have the correct shape
    if embedding1.shape[0] != expected_dim:
        embedding1 = np.pad(embedding1, (0, expected_dim - embedding1.shape[0]), 'constant')

    if embedding2.shape[0] != expected_dim:
        embedding2 = np.pad(embedding2, (0, expected_dim - embedding2.shape[0]), 'constant')

    # Concatenate the two embeddings to form a 400-d vector
    combined_embedding = np.concatenate((embedding1, embedding2))

    return combined_embedding


# Prepare stacking features on test data
stacking_features = []
valid_indices = []  # Track indices of rows with successful feature generation

for index, row in train_df.iterrows():
    drug1, drug2 = row['Drug1'], row['Drug2']
    
    try:
        # Get embeddings
        drug_embeddings = get_embeddings(drug1, drug2)

        # Get predictions from each model
        biobert_probs = get_biobert_prediction(drug1, drug2, row['Sentence'], biobert_model, biobert_tokenizer, device)

        # Ensure the embeddings are reshaped correctly for model input
        reshaped_embeddings = drug_embeddings.reshape(1, -1)  # Reshape for single sample

        # Get predictions from logistic and random forest models
        logistic_probs = logistic_model.predict(reshaped_embeddings)
        random_forest_probs = random_forest_model.predict(reshaped_embeddings)

        # Combine predictions as stacking features
        stacking_features.append(list(biobert_probs) + logistic_probs.tolist() + random_forest_probs.tolist())

        # Record the index as valid
        valid_indices.append(index)

    except ValueError as e:
        print(f"Error processing row {index}: {e}")

# Convert stacking features to DataFrame
X_stacking = pd.DataFrame(stacking_features)

# Filter y_stacking by valid indices
y_stacking = train_df.loc[valid_indices, 'Interaction'].reset_index(drop=True)

# %%
# Initialize the meta-classifier
stacking_model = LogisticRegression()

# Train the stacking model
stacking_model.fit(X_stacking, y_stacking)

# Predictions on the test data (optional if you already have a test set)
y_pred = stacking_model.predict(X_stacking)
print("Stacking Model Accuracy:", accuracy_score(y_stacking, y_pred))
print(classification_report(y_stacking, y_pred))
# Out:
# Stacking Model Accuracy: 0.9770437535981578
#               precision    recall  f1-score   support
#
#        false       0.98      0.99      0.99     23771
#         true       0.93      0.91      0.92      4021
#
#     accuracy                           0.98     27792
#    macro avg       0.96      0.95      0.95     27792
# weighted avg       0.98      0.98      0.98     27792

# %%
def get_embeddings(drug1, drug2, expected_dim=200):
    embedding1 = get_drug_embeddings(drug1, model)  # Fetch embedding for drug1
    embedding2 = get_drug_embeddings(drug2, model)  # Fetch embedding for drug2

    # Convert to numpy array if needed
    if isinstance(embedding1, dict):
        embedding1 = np.array(list(embedding1.values()))
    if isinstance(embedding2, dict):
        embedding2 = np.array(list(embedding2.values()))

    # Ensure embeddings are valid arrays
    if embedding1 is None or embedding1.size == 0:
        embedding1 = np.zeros(expected_dim)  # Pad missing embeddings
    if embedding2 is None or embedding2.size == 0:
        embedding2 = np.zeros(expected_dim)

    # Ensure embeddings have the correct shape
    if embedding1.shape[0] != expected_dim:
        embedding1 = np.pad(embedding1, (0, expected_dim - embedding1.shape[0]), 'constant')

    if embedding2.shape[0] != expected_dim:
        embedding2 = np.pad(embedding2, (0, expected_dim - embedding2.shape[0]), 'constant')

    # Concatenate the two embeddings to form a 400-d vector
    combined_embedding = np.concatenate((embedding1, embedding2))

    return combined_embedding
stacking_features = []
errors = []

# Process each test row
for index, row in test_df.iterrows():
    drug1, drug2 = row['Drug1'], row['Drug2']
    
    try:
        # Get embeddings
        drug_embeddings = get_embeddings(drug1, drug2)
        if drug_embeddings.size == 0:
            raise ValueError("Empty embeddings for drug pair.")

        # Generate predictions from individual models
        biobert_probs = get_biobert_prediction(drug1, drug2, row['Sentence'], biobert_model, biobert_tokenizer, device)

        reshaped_embeddings = drug_embeddings.reshape(1, -1)  # Reshape for single sample
        logistic_probs = logistic_model.predict(reshaped_embeddings)
        random_forest_probs = random_forest_model.predict(reshaped_embeddings)

        # Combine all predictions for stacking
        stacking_features.append(list(biobert_probs) + logistic_probs.tolist() + random_forest_probs.tolist())

    except ValueError as e:
        print(f"Error processing row {index}: {e}")
        errors.append(index)  # Track rows that caused errors

# Remove corresponding labels from y_stacking for rows with errors
test_df_cleaned = test_df.drop(errors)
X_stacking_test = pd.DataFrame(stacking_features)
y_stacking_test = test_df_cleaned['Interaction'].values  # Binary labels

# Make final predictions with the stacking model
stacking_predictions = stacking_model.predict(X_stacking_test)

# Evaluate the model performance
from sklearn.metrics import classification_report, accuracy_score

print("Classification Report:")
print(classification_report(y_stacking_test, stacking_predictions))
print("Accuracy:", accuracy_score(y_stacking_test, stacking_predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        false       0.96      0.98      0.97      4381
#         true       0.87      0.78      0.82       884
#
#     accuracy                           0.94      5265
#    macro avg       0.91      0.88      0.89      5265
# weighted avg       0.94      0.94      0.94      5265
#
# Accuracy: 0.9428300094966762

# %% [markdown]
# Save the trained stacking model

# %%
joblib.dump(stacking_model, "stacking_model.pkl")
print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
# Load the TwoSides_small dataset
two_sides_generated_df = pd.read_csv("../Dataset/twosides_generated_sentences.csv")

# Rename columns to Drug1, Drug2, Sentence
two_sides_generated_df.rename(columns={'drug_1_concept_name': 'Drug1', 'drug_2_concept_name': 'Drug2', 'generated_sentence': 'Sentence'}, inplace=True)

# %%
def predict_interaction_from_df(drug1, drug2, df):
    # Case-insensitive match
    match = df[((df['Drug1'].str.lower() == drug1.lower()) & (df['Drug2'].str.lower() == drug2.lower())) |
               ((df['Drug1'].str.lower() == drug2.lower()) & (df['Drug2'].str.lower() == drug1.lower()))]

    if match.empty:
        match = test_df[((test_df['Drug1'].str.lower() == drug1.lower()) & (test_df['Drug2'].str.lower() == drug2.lower())) |
                          ((test_df['Drug1'].str.lower() == drug2.lower()) & (test_df['Drug2'].str.lower() == drug1.lower()))]
        if match.empty:
            match = two_sides_generated_df[((two_sides_generated_df['Drug1'].str.lower() == drug1.lower()) & (two_sides_generated_df['Drug2'].str.lower() == drug2.lower())) |
                            ((two_sides_generated_df['Drug1'].str.lower() == drug2.lower()) & (two_sides_generated_df['Drug2'].str.lower() == drug1.lower()))]
            if match.empty:
                return "No matching sentence found in any dataset."

    # Use the first matching sentence
    sentence = match.iloc[0]['Sentence']

    try:
        drug_embeddings = get_embeddings(drug1, drug2)
        if drug_embeddings.size == 0:
            raise ValueError("Empty embeddings for drug pair.")

        biobert_probs = get_biobert_prediction(drug1, drug2, sentence, biobert_model, biobert_tokenizer, device)
        reshaped_embeddings = drug_embeddings.reshape(1, -1)
        logistic_probs = logistic_model.predict(reshaped_embeddings)
        random_forest_probs = random_forest_model.predict(reshaped_embeddings)

        # Stack features for final prediction
        combined_features = list(biobert_probs) + logistic_probs.tolist() + random_forest_probs.tolist()
        final_input = np.array(combined_features).reshape(1, -1)

        prediction = stacking_model.predict(final_input)
        return f"{'Interaction' if prediction[0] == 'true' else 'No Interaction'}"

    except Exception as e:
        return f"Error during prediction: {e}"

# %%
drug_alternatives = pd.read_csv("./drug_alternatives.csv")
drug_alternatives
# Out:
#                  drug                                      alternative_1  \
# 0         Bivalirudin                                        Semaglutide
# 1          Leuprolide                                          Buserelin
# 2           Goserelin                                          Nafarelin
# 3        Gramicidin D                                             Nerofe
# 4        Desmopressin                                          Lypressin
# ...               ...                                                ...
# 11908        Alogabat  4-(6-CYCLOHEXYLMETHOXY-9H-PURIN-2-YLAMINO)--BE...
# 11909    Ropsacitinib                                        Regadenoson
# 11910   taletrectinib                                            RU90395
# 11911    Tolebrutinib                                       Tirabrutinib
# 11912  Enmetazobactam  2'-O-Methyl-3'-Methyl-3'-Deoxy-Arabinofuranosy...
#
#                     alternative_2  \
# 0                       Avexitide
# 1                      Deslorelin
# 2                     Triptorelin
# 3                     Echinomycin
# 4                     Selepressin
# ...                           ...
# 11908                 Mizolastine
# 11909                 Vistusertib
# 11910                   Cadazolid
# 11911                   Ibrutinib
# 11912  Deoxyuridine monophosphate
#
#                                            alternative_3
# 0                                PP-F11N lutetium Lu-177
# 1                                                 Nerofe
# 2                                              Ganirelix
# 3                                             Reltecimod
# 4                                               Ozarelix
# ...                                                  ...
# 11908  N-cyclopropyl-4-methyl-3-{2-[(2-morpholin-4-yl...
# 11909                                      Golidocitinib
# 11910                                 Carotegrast methyl
# 11911                                      Edralbrutinib
# 11912                                          Sulopenem
#
# [11913 rows x 4 columns]

# %%
test_df
# Find drug pairs in test_df where both drugs are present in drug_alternatives
common_drug_pairs = test_df[
    (test_df['Drug1'].str.lower().isin(drug_alternatives['drug'].str.lower())) &
    (test_df['Drug2'].str.lower().isin(drug_alternatives['drug'].str.lower()))
]

common_drug_pairs.head()
# Out:
#           Drug1           Drug2  \
# 0  Ketoconazole     tolterodine
# 2  ketoconazole    itraconazole
# 3  ketoconazole      miconazole
# 5  ketoconazole    erythromycin
# 6  ketoconazole  clarithromycin
#
#                                             Sentence Interaction
# 0  CYP3A4 Inhibitors: Ketoconazole, an inhibitor ...        true
# 2  For patients receiving ketoconazole or other p...       false
# 3  For patients receiving ketoconazole or other p...       false
# 5  For patients receiving ketoconazole or other p...       false
# 6  For patients receiving ketoconazole or other p...       false

# %%
## Find drug pairs in two_sides_generated_df where both drugs are present in drug_alternatives
common_drug_pairs_two_sides = two_sides_generated_df[
    (two_sides_generated_df['Drug1'].str.lower().isin(drug_alternatives['drug'].str.lower())) &
    (two_sides_generated_df['Drug2'].str.lower().isin(drug_alternatives['drug'].str.lower()))
]

# In common_drug_pairs for interaction replace 0 with 'false' and 1 with 'true'
common_drug_pairs_two_sides['Interaction'] = common_drug_pairs_two_sides['Interaction'].replace({0: 'false', 1: 'true'})
common_drug_pairs_two_sides.head()
# Out:
# /var/folders/pv/wpg0wtcs5kj1758khrqy155m0000gn/T/ipykernel_6438/3856406649.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_drug_pairs_two_sides['Interaction'] = common_drug_pairs_two_sides['Interaction'].replace({0: 'false', 1: 'true'})
#           Drug1        Drug2  \
# 0  Levofloxacin   distigmine
# 2    irbesartan   Clonazepam
# 4    cortivazol    Oxacillin
# 6   Simvastatin   Loratadine
# 7    Raloxifene  milnacipran
#
#                                             Sentence Interaction
# 0  Levofloxacin does not interact with distigmine...       false
# 2  Using irbesartan concurrently with Clonazepam ...        true
# 4  Co-administration of cortivazol and Oxacillin ...       false
# 6  Simvastatin does not increase plasma concentra...        true
# 7  Raloxifene does not enhance the adverse effect...        true

# %%
interaction_count = common_drug_pairs[common_drug_pairs['Interaction'] == 'true'].shape[0]
print(f"Number of common drug pairs with interaction: {interaction_count}")

interaction_pairs = []
for index, row in common_drug_pairs.iterrows():
    drug1 = row['Drug1']
    drug2 = row['Drug2']
    interaction_pairs.append((drug1, drug2))
    # if row['Interaction'] == 'true':
    #     # Append the drug pair as a tuple
    #     interaction_pairs.append((drug1, drug2))
interaction_pairs
# Out:
# Number of common drug pairs with interaction: 218
# [('Ketoconazole', 'tolterodine'),
#  ('ketoconazole', 'itraconazole'),
#  ('ketoconazole', 'miconazole'),
#  ('ketoconazole', 'erythromycin'),
#  ('ketoconazole', 'clarithromycin'),
#  ('ketoconazole', 'cyclosporine'),
#  ('ketoconazole', 'vinblastine'),
#  ('itraconazole', 'miconazole'),
#  ('itraconazole', 'erythromycin'),
#  ('itraconazole', 'clarithromycin'),
#  ('itraconazole', 'cyclosporine'),
#  ('itraconazole', 'vinblastine'),
#  ('miconazole', 'erythromycin'),
#  ('miconazole', 'clarithromycin'),
#  ('miconazole', 'cyclosporine'),
#  ('miconazole', 'vinblastine'),
#  ('erythromycin', 'clarithromycin'),
#  ('erythromycin', 'cyclosporine'),
#  ('erythromycin', 'vinblastine'),
#  ('clarithromycin', 'cyclosporine'),
#  ('clarithromycin', 'vinblastine'),
#  ('cyclosporine', 'vinblastine'),
#  ('Paliperidone', 'levodopa'),
#  ('itraconazole', 'miconazole'),
#  ('itraconazole', 'erythromycin'),
#  ('itraconazole', 'clarithromycin'),
#  ('itraconazole', 'oxybutynin'),
#  ('miconazole', 'erythromycin'),
#  ('miconazole', 'clarithromycin'),
#  ('miconazole', 'oxybutynin'),
#  ('erythromycin', 'clarithromycin'),
#  ('erythromycin', 'oxybutynin'),
#  ('clarithromycin', 'oxybutynin'),
#  ('aluminum hydroxide', 'magnesium hydroxide'),
#  ('aluminum hydroxide', 'simethicone'),
#  ('aluminum hydroxide', 'oxybutynin'),
#  ('magnesium hydroxide', 'simethicone'),
#  ('magnesium hydroxide', 'oxybutynin'),
#  ('simethicone', 'oxybutynin'),
#  ('Mitotane', 'warfarin'),
#  ('Mitotane', 'warfarin'),
#  ('warfarin', 'warfarin'),
#  ('amphotericin B', 'bacitracin'),
#  ('amphotericin B', 'polymyxin B'),
#  ('amphotericin B', 'colistin'),
#  ('amphotericin B', 'viomycin'),
#  ('amphotericin B', 'cisplatin'),
#  ('bacitracin', 'polymyxin B'),
#  ('bacitracin', 'colistin'),
#  ('bacitracin', 'viomycin'),
#  ('bacitracin', 'cisplatin'),
#  ('polymyxin B', 'colistin'),
#  ('polymyxin B', 'viomycin'),
#  ('polymyxin B', 'cisplatin'),
#  ('colistin', 'viomycin'),
#  ('colistin', 'cisplatin'),
#  ('viomycin', 'cisplatin'),
#  ('clarithromycin', 'ranitidine'),
#  ('tigecycline', 'warfarin'),
#  ('atropine', 'triprolidine'),
#  ('dihydroergotamine', 'ergotamine'),
#  ('erythromycin', 'troleandomycin'),
#  ('erythromycin', 'clarithromycin'),
#  ('erythromycin', 'ritonavir'),
#  ('erythromycin', 'indinavir'),
#  ('erythromycin', 'nelfinavir'),
#  ('erythromycin', 'delavirdine'),
#  ('erythromycin', 'ketoconazole'),
#  ('erythromycin', 'itraconazole'),
#  ('erythromycin', 'voriconazole'),
#  ('troleandomycin', 'clarithromycin'),
#  ('troleandomycin', 'ritonavir'),
#  ('troleandomycin', 'indinavir'),
#  ('troleandomycin', 'nelfinavir'),
#  ('troleandomycin', 'delavirdine'),
#  ('troleandomycin', 'ketoconazole'),
#  ('troleandomycin', 'itraconazole'),
#  ('troleandomycin', 'voriconazole'),
#  ('clarithromycin', 'ritonavir'),
#  ('clarithromycin', 'indinavir'),
#  ('clarithromycin', 'nelfinavir'),
#  ('clarithromycin', 'delavirdine'),
#  ('clarithromycin', 'ketoconazole'),
#  ('clarithromycin', 'itraconazole'),
#  ('clarithromycin', 'voriconazole'),
#  ('ritonavir', 'indinavir'),
#  ('ritonavir', 'nelfinavir'),
#  ('ritonavir', 'delavirdine'),
#  ('ritonavir', 'ketoconazole'),
#  ('ritonavir', 'itraconazole'),
#  ('ritonavir', 'voriconazole'),
#  ('indinavir', 'nelfinavir'),
#  ('indinavir', 'delavirdine'),
#  ('indinavir', 'ketoconazole'),
#  ('indinavir', 'itraconazole'),
#  ('indinavir', 'voriconazole'),
#  ('nelfinavir', 'delavirdine'),
#  ('nelfinavir', 'ketoconazole'),
#  ('nelfinavir', 'itraconazole'),
#  ('nelfinavir', 'voriconazole'),
#  ('delavirdine', 'ketoconazole'),
#  ('delavirdine', 'itraconazole'),
#  ('delavirdine', 'voriconazole'),
#  ('ketoconazole', 'itraconazole'),
#  ('ketoconazole', 'voriconazole'),
#  ('itraconazole', 'voriconazole'),
#  ('saquinavir', 'nefazodone'),
#  ('saquinavir', 'fluconazole'),
#  ('saquinavir', 'fluoxetine'),
#  ('saquinavir', 'fluvoxamine'),
#  ('saquinavir', 'zileuton'),
#  ('saquinavir', 'clotrimazole'),
#  ('nefazodone', 'fluconazole'),
#  ('nefazodone', 'fluoxetine'),
#  ('nefazodone', 'fluvoxamine'),
#  ('nefazodone', 'zileuton'),
#  ('nefazodone', 'clotrimazole'),
#  ('fluconazole', 'fluoxetine'),
#  ('fluconazole', 'fluvoxamine'),
#  ('fluconazole', 'zileuton'),
#  ('fluconazole', 'clotrimazole'),
#  ('fluoxetine', 'fluvoxamine'),
#  ('fluoxetine', 'zileuton'),
#  ('fluoxetine', 'clotrimazole'),
#  ('fluvoxamine', 'zileuton'),
#  ('fluvoxamine', 'clotrimazole'),
#  ('zileuton', 'clotrimazole'),
#  ('trimetrexate', 'trimetrexate'),
#  ('trimetrexate', 'erythromycin'),
#  ('trimetrexate', 'rifabutin'),
#  ('trimetrexate', 'ketoconazole'),
#  ('trimetrexate', 'fluconazole'),
#  ('erythromycin', 'rifabutin'),
#  ('erythromycin', 'ketoconazole'),
#  ('erythromycin', 'fluconazole'),
#  ('rifabutin', 'ketoconazole'),
#  ('rifabutin', 'fluconazole'),
#  ('ketoconazole', 'fluconazole'),
#  ('cimetidine', 'trimetrexate'),
#  ('cimetidine', 'acetaminophen'),
#  ('trimetrexate', 'acetaminophen'),
#  ('clotrimazole', 'ketoconazole'),
#  ('clotrimazole', 'miconazole'),
#  ('clotrimazole', 'trimetrexate'),
#  ('ketoconazole', 'miconazole'),
#  ('ketoconazole', 'trimetrexate'),
#  ('miconazole', 'trimetrexate'),
#  ('mycophenolate mofetil', 'cyclosporine'),
#  ('mycophenolate mofetil', 'tacrolimus'),
#  ('mycophenolate mofetil', 'prednisolone'),
#  ('mycophenolate mofetil', 'sirolimus'),
#  ('mycophenolate mofetil', 'nifedipine'),
#  ('mycophenolate mofetil', 'fluconazole'),
#  ('mycophenolate mofetil', 'ritonavir'),
#  ('cyclosporine', 'tacrolimus'),
#  ('cyclosporine', 'prednisolone'),
#  ('cyclosporine', 'sirolimus'),
#  ('cyclosporine', 'nifedipine'),
#  ('cyclosporine', 'fluconazole'),
#  ('cyclosporine', 'ritonavir'),
#  ('tacrolimus', 'prednisolone'),
#  ('tacrolimus', 'sirolimus'),
#  ('tacrolimus', 'nifedipine'),
#  ('tacrolimus', 'fluconazole'),
#  ('tacrolimus', 'ritonavir'),
#  ('prednisolone', 'sirolimus'),
#  ('prednisolone', 'nifedipine'),
#  ('prednisolone', 'fluconazole'),
#  ('prednisolone', 'ritonavir'),
#  ('sirolimus', 'nifedipine'),
#  ('sirolimus', 'fluconazole'),
#  ('sirolimus', 'ritonavir'),
#  ('nifedipine', 'fluconazole'),
#  ('nifedipine', 'ritonavir'),
#  ('fluconazole', 'ritonavir'),
#  ('mycophenolate mofetil', 'cyclosporine'),
#  ('mycophenolate mofetil', 'tacrolimus'),
#  ('mycophenolate mofetil', 'prednisolone'),
#  ('mycophenolate mofetil', 'fluconazole'),
#  ('cyclosporine', 'tacrolimus'),
#  ('cyclosporine', 'prednisolone'),
#  ('cyclosporine', 'fluconazole'),
#  ('tacrolimus', 'prednisolone'),
#  ('tacrolimus', 'fluconazole'),
#  ('prednisolone', 'fluconazole'),
#  ('Sirolimus', 'sirolimus'),
#  ('Nifedipine', 'nifedipine'),
#  ('sirolimus', 'nifedipine'),
#  ('sirolimus', 'sirolimus'),
#  ('sirolimus', 'nifedipine'),
#  ('sirolimus', 'sirolimus'),
#  ('sirolimus', 'nifedipine'),
#  ('nifedipine', 'sirolimus'),
#  ('nifedipine', 'nifedipine'),
#  ('nifedipine', 'sirolimus'),
#  ('nifedipine', 'nifedipine'),
#  ('sirolimus', 'nifedipine'),
#  ('sirolimus', 'sirolimus'),
#  ('sirolimus', 'nifedipine'),
#  ('nifedipine', 'sirolimus'),
#  ('nifedipine', 'nifedipine'),
#  ('sirolimus', 'nifedipine'),
#  ('Caffeine', 'ephedrine'),
#  ('Caffeine', 'amphetamine'),
#  ('ephedrine', 'amphetamine'),
#  ('succinylcholine', 'succinylcholine'),
#  ('Isoflurane', 'enflurane'),
#  ('Isoflurane', 'nitrous oxide'),
#  ('Isoflurane', 'oxygen'),
#  ('enflurane', 'nitrous oxide'),
#  ('enflurane', 'oxygen'),
#  ('nitrous oxide', 'oxygen'),
#  ('enflurane', 'isoflurane'),
#  ('bacitracin', 'lincomycin'),
#  ('bacitracin', 'clindamycin'),
#  ('bacitracin', 'colistin'),
#  ('bacitracin', 'magnesium'),
#  ('bacitracin', 'procainamide'),
#  ('bacitracin', 'quinidine'),
#  ('lincomycin', 'clindamycin'),
#  ('lincomycin', 'colistin'),
#  ('lincomycin', 'magnesium'),
#  ('lincomycin', 'procainamide'),
#  ('lincomycin', 'quinidine'),
#  ('clindamycin', 'colistin'),
#  ('clindamycin', 'magnesium'),
#  ('clindamycin', 'procainamide'),
#  ('clindamycin', 'quinidine'),
#  ('colistin', 'magnesium'),
#  ('colistin', 'procainamide'),
#  ('colistin', 'quinidine'),
#  ('magnesium', 'procainamide'),
#  ('magnesium', 'quinidine'),
#  ('procainamide', 'quinidine'),
#  ('phenytoin', 'carbamazepine'),
#  ('phenytoin', 'carbamazepine'),
#  ('phenytoin', 'carbamazepine'),
#  ('phenytoin', 'cisplatin'),
#  ('phenytoin', 'edrophonium'),
#  ('phenytoin', 'neostigmine'),
#  ('phenytoin', 'polymyxin B'),
#  ('phenytoin', 'bacitracin'),
#  ('phenytoin', 'procaine'),
#  ('phenytoin', 'succinylcholine'),
#  ('carbamazepine', 'cisplatin'),
#  ('carbamazepine', 'edrophonium'),
#  ('carbamazepine', 'neostigmine'),
#  ('carbamazepine', 'polymyxin B'),
#  ('carbamazepine', 'bacitracin'),
#  ('carbamazepine', 'procaine'),
#  ('carbamazepine', 'succinylcholine'),
#  ('cisplatin', 'edrophonium'),
#  ('cisplatin', 'neostigmine'),
#  ('cisplatin', 'polymyxin B'),
#  ('cisplatin', 'bacitracin'),
#  ('cisplatin', 'procaine'),
#  ('cisplatin', 'succinylcholine'),
#  ('edrophonium', 'neostigmine'),
#  ('edrophonium', 'polymyxin B'),
#  ('edrophonium', 'bacitracin'),
#  ('edrophonium', 'procaine'),
#  ('edrophonium', 'succinylcholine'),
#  ('neostigmine', 'polymyxin B'),
#  ('neostigmine', 'bacitracin'),
#  ('neostigmine', 'procaine'),
#  ('neostigmine', 'succinylcholine'),
#  ('polymyxin B', 'bacitracin'),
#  ('polymyxin B', 'procaine'),
#  ('polymyxin B', 'succinylcholine'),
#  ('bacitracin', 'procaine'),
#  ('bacitracin', 'succinylcholine'),
#  ('procaine', 'succinylcholine'),
#  ('solifenacin', 'solifenacin'),
#  ('solifenacin', 'solifenacin'),
#  ('solifenacin', 'moxifloxacin'),
#  ('solifenacin', 'solifenacin'),
#  ('solifenacin', 'moxifloxacin'),
#  ('solifenacin', 'moxifloxacin'),
#  ('Guanethidine', 'minoxidil'),
#  ('Guanethidine', 'guanethidine'),
#  ('minoxidil', 'guanethidine'),
#  ('guanethidine', 'minoxidil'),
#  ('spironolactone', 'amiloride'),
#  ('spironolactone', 'triamterene'),
#  ('spironolactone', 'potassium'),
#  ('spironolactone', 'indomethacin'),
#  ('spironolactone', 'cyclosporine'),
#  ('amiloride', 'triamterene'),
#  ('amiloride', 'potassium'),
#  ('amiloride', 'indomethacin'),
#  ('amiloride', 'cyclosporine'),
#  ('triamterene', 'potassium'),
#  ('triamterene', 'indomethacin'),
#  ('triamterene', 'cyclosporine'),
#  ('potassium', 'indomethacin'),
#  ('potassium', 'cyclosporine'),
#  ('indomethacin', 'cyclosporine'),
#  ('Digoxin', 'digoxin'),
#  ('Digoxin', 'digoxin'),
#  ('Digoxin', 'perindopril'),
#  ('Digoxin', 'perindoprilat'),
#  ('digoxin', 'digoxin'),
#  ('digoxin', 'perindopril'),
#  ('digoxin', 'perindoprilat'),
#  ('digoxin', 'perindopril'),
#  ('digoxin', 'perindoprilat'),
#  ('perindopril', 'perindoprilat'),
#  ('Gentamicin', 'perindopril'),
#  ('Gentamicin', 'gentamicin'),
#  ('perindopril', 'gentamicin'),
#  ('perindopril', 'perindoprilat'),
#  ('valproic acid', 'temozolomide'),
#  ('tolbutamide', 'sulfamethizole'),
#  ('tolbutamide', 'teniposide'),
#  ('sulfamethizole', 'teniposide'),
#  ('teniposide', 'methotrexate'),
#  ('methotrexate', 'teniposide'),
#  ('Theophylline', 'Theophylline'),
#  ('Theophylline', 'theophylline'),
#  ('Theophylline', 'theophylline'),
#  ('Furosemide', 'metolazone'),
#  ('Metolazone', 'norepinephrine'),
#  ('Methenamine', 'metolazone'),
#  ('amantadine', 'quinidine'),
#  ('amantadine', 'meperidine'),
#  ('quinidine', 'meperidine'),
#  ('ropivacaine', 'fluvoxamine'),
#  ('fluvoxamine', 'Ropivacaine'),
#  ('fluvoxamine', 'Ropivacaine'),
#  ('fluvoxamine', 'ropivacaine'),
#  ('Ropivacaine', 'Ropivacaine'),
#  ('Ropivacaine', 'ropivacaine'),
#  ('Ropivacaine', 'ropivacaine'),
#  ('theophylline', 'imipramine'),
#  ('ketoconazole', 'ropivacaine'),
#  ('ketoconazole', 'ketoconazole'),
#  ('ketoconazole', 'ropivacaine'),
#  ('ropivacaine', 'ketoconazole'),
#  ('ropivacaine', 'ropivacaine'),
#  ('ketoconazole', 'ropivacaine'),
#  ('sulfamethoxazole', 'warfarin'),
#  ('Sulfamethoxazole', 'phenytoin'),
#  ('sulfamethoxazole', 'phenytoin'),
#  ('methotrexate', 'methotrexate'),
#  ('olsalazine', 'mesalazine'),
#  ('Thalidomide', 'chlorpromazine'),
#  ('Thalidomide', 'reserpine'),
#  ('chlorpromazine', 'reserpine'),
#  ('Thalidomide', 'griseofulvin'),
#  ('Thalidomide', 'modafinil'),
#  ('Thalidomide', 'rifabutin'),
#  ('Thalidomide', 'phenytoin'),
#  ('Thalidomide', 'carbamazepine'),
#  ('griseofulvin', 'modafinil'),
#  ('griseofulvin', 'rifabutin'),
#  ('griseofulvin', 'phenytoin'),
#  ('griseofulvin', 'carbamazepine'),
#  ('modafinil', 'rifabutin'),
#  ('modafinil', 'phenytoin'),
#  ('modafinil', 'carbamazepine'),
#  ('rifabutin', 'phenytoin'),
#  ('rifabutin', 'carbamazepine'),
#  ('phenytoin', 'carbamazepine'),
#  ('Montelukast', 'theophylline'),
#  ('warfarin', 'warfarin'),
#  ('terfenadine', 'fexofenadine'),
#  ('terfenadine', 'terfenadine'),
#  ('fexofenadine', 'terfenadine'),
#  ('Montelukast', 'estradiol'),
#  ('prednisone', 'prednisolone'),
#  ('prednisone', 'prednisone'),
#  ('prednisone', 'prednisolone'),
#  ('prednisolone', 'prednisone'),
#  ('prednisolone', 'prednisolone'),
#  ('prednisone', 'prednisolone'),
#  ('Phenobarbital', 'montelukast'),
#  ('Phenobarbital', 'montelukast'),
#  ('montelukast', 'montelukast'),
#  ('phenobarbital', 'montelukast'),
#  ('montelukast', 'theophylline'),
#  ('montelukast', 'prednisone'),
#  ('montelukast', 'prednisolone'),
#  ('montelukast', 'terfenadine'),
#  ('montelukast', 'digoxin'),
#  ('montelukast', 'warfarin'),
#  ('theophylline', 'prednisone'),
#  ('theophylline', 'prednisolone'),
#  ('theophylline', 'terfenadine'),
#  ('theophylline', 'digoxin'),
#  ('theophylline', 'warfarin'),
#  ('prednisone', 'prednisolone'),
#  ('prednisone', 'terfenadine'),
#  ('prednisone', 'digoxin'),
#  ('prednisone', 'warfarin'),
#  ('prednisolone', 'terfenadine'),
#  ('prednisolone', 'digoxin'),
#  ('prednisolone', 'warfarin'),
#  ('terfenadine', 'digoxin'),
#  ('terfenadine', 'warfarin'),
#  ('digoxin', 'warfarin'),
#  ('Phenobarbital', 'montelukast'),
#  ('Phenobarbital', 'montelukast'),
#  ('montelukast', 'montelukast'),
#  ('phenobarbital', 'montelukast'),
#  ('Carbidopa', 'Levodopa'),
#  ('Carbidopa', 'Carbidopa'),
#  ('Carbidopa', 'Levodopa'),
#  ('Carbidopa', 'pramipexole'),
#  ('Levodopa', 'Carbidopa'),
#  ('Levodopa', 'Levodopa'),
#  ('Levodopa', 'pramipexole'),
#  ('Carbidopa', 'Levodopa'),
#  ('Carbidopa', 'pramipexole'),
#  ('Levodopa', 'pramipexole'),
#  ('Selegiline', 'selegiline'),
#  ('Selegiline', 'pramipexole'),
#  ('selegiline', 'pramipexole'),
#  ('Amantadine', 'amantadine'),
#  ('Amantadine', 'pramipexole'),
#  ('amantadine', 'pramipexole'),
#  ('Cimetidine', 'Cimetidine'),
#  ('Cimetidine', 'pramipexole'),
#  ('Cimetidine', 'pramipexole'),
#  ('Probenecid', 'Probenecid'),
#  ('Probenecid', 'pramipexole'),
#  ('Probenecid', 'pramipexole'),
#  ('cimetidine', 'ranitidine'),
#  ('cimetidine', 'diltiazem'),
#  ('cimetidine', 'triamterene'),
#  ('cimetidine', 'verapamil'),
#  ('cimetidine', 'quinidine'),
#  ('cimetidine', 'quinine'),
#  ('cimetidine', 'pramipexole'),
#  ('cimetidine', 'indomethacin'),
#  ('cimetidine', 'hydrochlorothiazide'),
#  ('cimetidine', 'chlorpropamide'),
#  ('cimetidine', 'pramipexole'),
#  ('ranitidine', 'diltiazem'),
#  ('ranitidine', 'triamterene'),
#  ('ranitidine', 'verapamil'),
#  ('ranitidine', 'quinidine'),
#  ('ranitidine', 'quinine'),
#  ('ranitidine', 'pramipexole'),
#  ('ranitidine', 'indomethacin'),
#  ('ranitidine', 'hydrochlorothiazide'),
#  ('ranitidine', 'chlorpropamide'),
#  ('ranitidine', 'pramipexole'),
#  ('diltiazem', 'triamterene'),
#  ('diltiazem', 'verapamil'),
#  ('diltiazem', 'quinidine'),
#  ('diltiazem', 'quinine'),
#  ('diltiazem', 'pramipexole'),
#  ('diltiazem', 'indomethacin'),
#  ('diltiazem', 'hydrochlorothiazide'),
#  ('diltiazem', 'chlorpropamide'),
#  ('diltiazem', 'pramipexole'),
#  ('triamterene', 'verapamil'),
#  ('triamterene', 'quinidine'),
#  ('triamterene', 'quinine'),
#  ('triamterene', 'pramipexole'),
#  ('triamterene', 'indomethacin'),
#  ('triamterene', 'hydrochlorothiazide'),
#  ('triamterene', 'chlorpropamide'),
#  ('triamterene', 'pramipexole'),
#  ('verapamil', 'quinidine'),
#  ('verapamil', 'quinine'),
#  ('verapamil', 'pramipexole'),
#  ('verapamil', 'indomethacin'),
#  ('verapamil', 'hydrochlorothiazide'),
#  ('verapamil', 'chlorpropamide'),
#  ('verapamil', 'pramipexole'),
#  ('quinidine', 'quinine'),
#  ('quinidine', 'pramipexole'),
#  ('quinidine', 'indomethacin'),
#  ('quinidine', 'hydrochlorothiazide'),
#  ('quinidine', 'chlorpropamide'),
#  ('quinidine', 'pramipexole'),
#  ('quinine', 'pramipexole'),
#  ('quinine', 'indomethacin'),
#  ('quinine', 'hydrochlorothiazide'),
#  ('quinine', 'chlorpropamide'),
#  ('quinine', 'pramipexole'),
#  ('pramipexole', 'indomethacin'),
#  ('pramipexole', 'hydrochlorothiazide'),
#  ('pramipexole', 'chlorpropamide'),
#  ('pramipexole', 'pramipexole'),
#  ('indomethacin', 'hydrochlorothiazide'),
#  ('indomethacin', 'chlorpropamide'),
#  ('indomethacin', 'pramipexole'),
#  ('hydrochlorothiazide', 'chlorpropamide'),
#  ('hydrochlorothiazide', 'pramipexole'),
#  ('chlorpropamide', 'pramipexole'),
#  ('pramipexole', 'pramipexole'),
#  ('pramipexole', 'metoclopramide'),
#  ('pantoprazole', 'theophylline'),
#  ('pantoprazole', 'cisapride'),
#  ('pantoprazole', 'antipyrine'),
#  ('pantoprazole', 'caffeine'),
#  ('pantoprazole', 'carbamazepine'),
#  ('pantoprazole', 'diazepam'),
#  ('pantoprazole', 'diclofenac'),
#  ('pantoprazole', 'naproxen'),
#  ('pantoprazole', 'piroxicam'),
#  ('pantoprazole', 'digoxin'),
#  ('pantoprazole', 'ethanol'),
#  ('pantoprazole', 'glyburide'),
#  ('pantoprazole', 'levonorgestrel'),
#  ('pantoprazole', 'metoprolol'),
#  ('pantoprazole', 'nifedipine'),
#  ('pantoprazole', 'phenytoin'),
#  ('pantoprazole', 'warfarin'),
#  ('pantoprazole', 'midazolam'),
#  ('pantoprazole', 'clarithromycin'),
#  ('pantoprazole', 'metronidazole'),
#  ('pantoprazole', 'amoxicillin'),
#  ('theophylline', 'cisapride'),
#  ('theophylline', 'antipyrine'),
#  ('theophylline', 'caffeine'),
#  ('theophylline', 'carbamazepine'),
#  ('theophylline', 'diazepam'),
#  ('theophylline', 'diclofenac'),
#  ('theophylline', 'naproxen'),
#  ('theophylline', 'piroxicam'),
#  ('theophylline', 'digoxin'),
#  ('theophylline', 'ethanol'),
#  ('theophylline', 'glyburide'),
#  ('theophylline', 'levonorgestrel'),
#  ('theophylline', 'metoprolol'),
#  ('theophylline', 'nifedipine'),
#  ('theophylline', 'phenytoin'),
#  ('theophylline', 'warfarin'),
#  ('theophylline', 'midazolam'),
#  ('theophylline', 'clarithromycin'),
#  ('theophylline', 'metronidazole'),
#  ('theophylline', 'amoxicillin'),
#  ('cisapride', 'antipyrine'),
#  ('cisapride', 'caffeine'),
#  ('cisapride', 'carbamazepine'),
#  ('cisapride', 'diazepam'),
#  ('cisapride', 'diclofenac'),
#  ('cisapride', 'naproxen'),
#  ('cisapride', 'piroxicam'),
#  ('cisapride', 'digoxin'),
#  ('cisapride', 'ethanol'),
#  ('cisapride', 'glyburide'),
#  ('cisapride', 'levonorgestrel'),
#  ('cisapride', 'metoprolol'),
#  ('cisapride', 'nifedipine'),
#  ('cisapride', 'phenytoin'),
#  ('cisapride', 'warfarin'),
#  ('cisapride', 'midazolam'),
#  ('cisapride', 'clarithromycin'),
#  ('cisapride', 'metronidazole'),
#  ('cisapride', 'amoxicillin'),
#  ('antipyrine', 'caffeine'),
#  ('antipyrine', 'carbamazepine'),
#  ('antipyrine', 'diazepam'),
#  ('antipyrine', 'diclofenac'),
#  ('antipyrine', 'naproxen'),
#  ('antipyrine', 'piroxicam'),
#  ('antipyrine', 'digoxin'),
#  ('antipyrine', 'ethanol'),
#  ('antipyrine', 'glyburide'),
#  ('antipyrine', 'levonorgestrel'),
#  ('antipyrine', 'metoprolol'),
#  ('antipyrine', 'nifedipine'),
#  ('antipyrine', 'phenytoin'),
#  ('antipyrine', 'warfarin'),
#  ('antipyrine', 'midazolam'),
#  ('antipyrine', 'clarithromycin'),
#  ('antipyrine', 'metronidazole'),
#  ('antipyrine', 'amoxicillin'),
#  ('caffeine', 'carbamazepine'),
#  ('caffeine', 'diazepam'),
#  ('caffeine', 'diclofenac'),
#  ('caffeine', 'naproxen'),
#  ('caffeine', 'piroxicam'),
#  ('caffeine', 'digoxin'),
#  ('caffeine', 'ethanol'),
#  ('caffeine', 'glyburide'),
#  ('caffeine', 'levonorgestrel'),
#  ('caffeine', 'metoprolol'),
#  ('caffeine', 'nifedipine'),
#  ('caffeine', 'phenytoin'),
#  ('caffeine', 'warfarin'),
#  ('caffeine', 'midazolam'),
#  ('caffeine', 'clarithromycin'),
#  ('caffeine', 'metronidazole'),
#  ('caffeine', 'amoxicillin'),
#  ('carbamazepine', 'diazepam'),
#  ('carbamazepine', 'diclofenac'),
#  ('carbamazepine', 'naproxen'),
#  ('carbamazepine', 'piroxicam'),
#  ('carbamazepine', 'digoxin'),
#  ('carbamazepine', 'ethanol'),
#  ('carbamazepine', 'glyburide'),
#  ('carbamazepine', 'levonorgestrel'),
#  ('carbamazepine', 'metoprolol'),
#  ('carbamazepine', 'nifedipine'),
#  ('carbamazepine', 'phenytoin'),
#  ('carbamazepine', 'warfarin'),
#  ('carbamazepine', 'midazolam'),
#  ('carbamazepine', 'clarithromycin'),
#  ('carbamazepine', 'metronidazole'),
#  ('carbamazepine', 'amoxicillin'),
#  ('diazepam', 'diclofenac'),
#  ('diazepam', 'naproxen'),
#  ('diazepam', 'piroxicam'),
#  ('diazepam', 'digoxin'),
#  ('diazepam', 'ethanol'),
#  ('diazepam', 'glyburide'),
#  ('diazepam', 'levonorgestrel'),
#  ('diazepam', 'metoprolol'),
#  ('diazepam', 'nifedipine'),
#  ('diazepam', 'phenytoin'),
#  ('diazepam', 'warfarin'),
#  ('diazepam', 'midazolam'),
#  ('diazepam', 'clarithromycin'),
#  ('diazepam', 'metronidazole'),
#  ('diazepam', 'amoxicillin'),
#  ('diclofenac', 'naproxen'),
#  ('diclofenac', 'piroxicam'),
#  ('diclofenac', 'digoxin'),
#  ('diclofenac', 'ethanol'),
#  ('diclofenac', 'glyburide'),
#  ('diclofenac', 'levonorgestrel'),
#  ('diclofenac', 'metoprolol'),
#  ('diclofenac', 'nifedipine'),
#  ('diclofenac', 'phenytoin'),
#  ('diclofenac', 'warfarin'),
#  ('diclofenac', 'midazolam'),
#  ('diclofenac', 'clarithromycin'),
#  ('diclofenac', 'metronidazole'),
#  ('diclofenac', 'amoxicillin'),
#  ('naproxen', 'piroxicam'),
#  ('naproxen', 'digoxin'),
#  ('naproxen', 'ethanol'),
#  ('naproxen', 'glyburide'),
#  ('naproxen', 'levonorgestrel'),
#  ('naproxen', 'metoprolol'),
#  ('naproxen', 'nifedipine'),
#  ('naproxen', 'phenytoin'),
#  ('naproxen', 'warfarin'),
#  ('naproxen', 'midazolam'),
#  ('naproxen', 'clarithromycin'),
#  ('naproxen', 'metronidazole'),
#  ('naproxen', 'amoxicillin'),
#  ('piroxicam', 'digoxin'),
#  ('piroxicam', 'ethanol'),
#  ('piroxicam', 'glyburide'),
#  ('piroxicam', 'levonorgestrel'),
#  ('piroxicam', 'metoprolol'),
#  ('piroxicam', 'nifedipine'),
#  ('piroxicam', 'phenytoin'),
#  ('piroxicam', 'warfarin'),
#  ('piroxicam', 'midazolam'),
#  ('piroxicam', 'clarithromycin'),
#  ('piroxicam', 'metronidazole'),
#  ('piroxicam', 'amoxicillin'),
#  ('digoxin', 'ethanol'),
#  ('digoxin', 'glyburide'),
#  ('digoxin', 'levonorgestrel'),
#  ('digoxin', 'metoprolol'),
#  ('digoxin', 'nifedipine'),
#  ('digoxin', 'phenytoin'),
#  ('digoxin', 'warfarin'),
#  ('digoxin', 'midazolam'),
#  ('digoxin', 'clarithromycin'),
#  ('digoxin', 'metronidazole'),
#  ('digoxin', 'amoxicillin'),
#  ('ethanol', 'glyburide'),
#  ('ethanol', 'levonorgestrel'),
#  ('ethanol', 'metoprolol'),
#  ('ethanol', 'nifedipine'),
#  ('ethanol', 'phenytoin'),
#  ('ethanol', 'warfarin'),
#  ('ethanol', 'midazolam'),
#  ('ethanol', 'clarithromycin'),
#  ('ethanol', 'metronidazole'),
#  ('ethanol', 'amoxicillin'),
#  ('glyburide', 'levonorgestrel'),
#  ('glyburide', 'metoprolol'),
#  ('glyburide', 'nifedipine'),
#  ('glyburide', 'phenytoin'),
#  ('glyburide', 'warfarin'),
#  ('glyburide', 'midazolam'),
#  ('glyburide', 'clarithromycin'),
#  ('glyburide', 'metronidazole'),
#  ('glyburide', 'amoxicillin'),
#  ('levonorgestrel', 'metoprolol'),
#  ('levonorgestrel', 'nifedipine'),
#  ('levonorgestrel', 'phenytoin'),
#  ('levonorgestrel', 'warfarin'),
#  ('levonorgestrel', 'midazolam'),
#  ('levonorgestrel', 'clarithromycin'),
#  ('levonorgestrel', 'metronidazole'),
#  ('levonorgestrel', 'amoxicillin'),
#  ('metoprolol', 'nifedipine'),
#  ('metoprolol', 'phenytoin'),
#  ('metoprolol', 'warfarin'),
#  ('metoprolol', 'midazolam'),
#  ('metoprolol', 'clarithromycin'),
#  ('metoprolol', 'metronidazole'),
#  ('metoprolol', 'amoxicillin'),
#  ('nifedipine', 'phenytoin'),
#  ('nifedipine', 'warfarin'),
#  ('nifedipine', 'midazolam'),
#  ('nifedipine', 'clarithromycin'),
#  ('nifedipine', 'metronidazole'),
#  ('nifedipine', 'amoxicillin'),
#  ('phenytoin', 'warfarin'),
#  ('phenytoin', 'midazolam'),
#  ('phenytoin', 'clarithromycin'),
#  ('phenytoin', 'metronidazole'),
#  ('phenytoin', 'amoxicillin'),
#  ('warfarin', 'midazolam'),
#  ('warfarin', 'clarithromycin'),
#  ('warfarin', 'metronidazole'),
#  ('warfarin', 'amoxicillin'),
#  ('midazolam', 'clarithromycin'),
#  ('midazolam', 'metronidazole'),
#  ('midazolam', 'amoxicillin'),
#  ('clarithromycin', 'metronidazole'),
#  ('clarithromycin', 'amoxicillin'),
#  ('metronidazole', 'amoxicillin'),
#  ('pantoprazole', 'pantoprazole'),
#  ('pantoprazole', 'warfarin'),
#  ('pantoprazole', 'ketoconazole'),
#  ('pantoprazole', 'ampicillin'),
#  ('pantoprazole', 'iron'),
#  ('ketoconazole', 'ampicillin'),
#  ('ketoconazole', 'iron'),
#  ('ampicillin', 'iron'),
#  ('mazindol', 'isocarboxazid'),
#  ('mazindol', 'tranylcypromine'),
#  ('mazindol', 'phenelzine'),
#  ('isocarboxazid', 'tranylcypromine'),
#  ('isocarboxazid', 'phenelzine'),
#  ('tranylcypromine', 'phenelzine'),
#  ('Mazindol', 'guanethidine'),
#  ('amitriptyline', 'amoxapine'),
#  ('amitriptyline', 'doxepin'),
#  ('amitriptyline', 'nortriptyline'),
#  ('amitriptyline', 'imipramine'),
#  ('amitriptyline', 'clomipramine'),
#  ('amitriptyline', 'protriptyline'),
#  ('amitriptyline', 'desipramine'),
#  ('amoxapine', 'doxepin'),
#  ('amoxapine', 'nortriptyline'),
#  ('amoxapine', 'imipramine'),
#  ('amoxapine', 'clomipramine'),
#  ('amoxapine', 'protriptyline'),
#  ('amoxapine', 'desipramine'),
#  ('doxepin', 'nortriptyline'),
#  ('doxepin', 'imipramine'),
#  ('doxepin', 'clomipramine'),
#  ('doxepin', 'protriptyline'),
#  ('doxepin', 'desipramine'),
#  ('nortriptyline', 'imipramine'),
#  ('nortriptyline', 'clomipramine'),
#  ('nortriptyline', 'protriptyline'),
#  ('nortriptyline', 'desipramine'),
#  ('imipramine', 'clomipramine'),
#  ('imipramine', 'protriptyline'),
#  ('imipramine', 'desipramine'),
#  ('clomipramine', 'protriptyline'),
#  ('clomipramine', 'desipramine'),
#  ('protriptyline', 'desipramine'),
#  ('abacavir', 'lamivudine'),
#  ('abacavir', 'zidovudine'),
#  ('abacavir', 'lamivudine'),
#  ('abacavir', 'zidovudine'),
#  ('lamivudine', 'zidovudine'),
#  ('lamivudine', 'lamivudine'),
#  ('lamivudine', 'zidovudine'),
#  ('zidovudine', 'lamivudine'),
#  ('zidovudine', 'zidovudine'),
#  ('lamivudine', 'zidovudine'),
#  ('lamivudine', 'zidovudine'),
#  ('lamivudine', 'abacavir'),
#  ('zidovudine', 'abacavir'),
#  ('Abacavir', 'ethanol'),
#  ('Ethanol', 'abacavir'),
#  ('Ethanol', 'methadone'),
#  ('Ethanol', 'abacavir'),
#  ('abacavir', 'methadone'),
#  ('abacavir', 'abacavir'),
#  ('methadone', 'abacavir'),
#  ('methadone', 'methadone'),
#  ('Sulfoxone', 'tolbutamide'),
#  ('cyclosporine', 'warfarin'),
#  ('cyclosporine', 'methotrexate'),
#  ('cyclosporine', 'methotrexate'),
#  ('cyclosporine', 'phenytoin'),
#  ('cyclosporine', 'phenytoin'),
#  ('warfarin', 'methotrexate'),
#  ('warfarin', 'methotrexate'),
#  ('warfarin', 'phenytoin'),
#  ('warfarin', 'phenytoin'),
#  ('methotrexate', 'methotrexate'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('phenytoin', 'phenytoin'),
#  ('zidovudine', 'rifabutin'),
#  ('zidovudine', 'megestrol acetate'),
#  ('rifabutin', 'megestrol acetate'),
#  ('megestrol acetate', 'indinavir'),
#  ('megestrol acetate', 'indinavir'),
#  ('indinavir', 'indinavir'),
#  ('indinavir', 'megestrol acetate'),
#  ('indinavir', 'zidovudine'),
#  ('indinavir', 'rifabutin'),
#  ('indinavir', 'megestrol acetate'),
#  ('zidovudine', 'rifabutin'),
#  ('zidovudine', 'megestrol acetate'),
#  ('rifabutin', 'megestrol acetate'),
#  ('Streptozocin', 'doxorubicin'),
#  ('streptozocin', 'phenytoin'),
#  ('streptozocin', 'streptozocin'),
#  ('phenytoin', 'streptozocin'),
#  ('quinidine', 'theophylline'),
#  ('Sulfamethizole', 'tolbutamide'),
#  ('cyclosporine', 'warfarin'),
#  ('cyclosporine', 'methotrexate'),
#  ('cyclosporine', 'methotrexate'),
#  ('cyclosporine', 'phenytoin'),
#  ('cyclosporine', 'phenytoin'),
#  ('warfarin', 'methotrexate'),
#  ('warfarin', 'methotrexate'),
#  ('warfarin', 'phenytoin'),
#  ('warfarin', 'phenytoin'),
#  ('methotrexate', 'methotrexate'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('methotrexate', 'phenytoin'),
#  ('phenytoin', 'phenytoin'),
#  ('acetylsalicylic acid', 'dipyridamole'),
#  ('Cimetidine', 'cimetidine'),
#  ('Cimetidine', 'rimantadine'),
#  ('cimetidine', 'rimantadine'),
#  ('Cimetidine', 'rimantadine'),
#  ('Cimetidine', 'rimantadine'),
#  ('Cimetidine', 'cimetidine'),
#  ('rimantadine', 'rimantadine'),
#  ('rimantadine', 'cimetidine'),
#  ('rimantadine', 'cimetidine'),
#  ('acetaminophen', 'rimantadine'),
#  ('Trimethoprim', 'phenytoin'),
#  ('Trimethoprim', 'phenytoin'),
#  ('Trimethoprim', 'phenytoin'),
#  ('phenytoin', 'phenytoin'),
#  ('atropine', 'ipratropium'),
#  ('acetylsalicylic acid', 'calcium'),
#  ('acetylsalicylic acid', 'ibuprofen'),
#  ('acetylsalicylic acid', 'medroxyprogesterone acetate'),
#  ('acetylsalicylic acid', 'methotrexate'),
#  ('acetylsalicylic acid', 'naproxen'),
#  ('acetylsalicylic acid', 'omeprazole'),
#  ('acetylsalicylic acid', 'prednisone'),
#  ('calcium', 'ibuprofen'),
#  ('calcium', 'medroxyprogesterone acetate'),
#  ('calcium', 'methotrexate'),
#  ('calcium', 'naproxen'),
#  ('calcium', 'omeprazole'),
#  ('calcium', 'prednisone'),
#  ('ibuprofen', 'medroxyprogesterone acetate'),
#  ('ibuprofen', 'methotrexate'),
#  ('ibuprofen', 'naproxen'),
#  ('ibuprofen', 'omeprazole'),
#  ('ibuprofen', 'prednisone'),
#  ('medroxyprogesterone acetate', 'methotrexate'),
#  ('medroxyprogesterone acetate', 'naproxen'),
#  ('medroxyprogesterone acetate', 'omeprazole'),
#  ('medroxyprogesterone acetate', 'prednisone'),
#  ('methotrexate', 'naproxen'),
#  ('methotrexate', 'omeprazole'),
#  ('methotrexate', 'prednisone'),
#  ('naproxen', 'omeprazole'),
#  ('naproxen', 'prednisone'),
#  ('omeprazole', 'prednisone'),
#  ('phenobarbital', 'phenytoin'),
#  ('phenobarbital', 'methylprednisolone'),
#  ('phenobarbital', 'methylprednisolone'),
#  ('phenytoin', 'methylprednisolone'),
#  ('phenytoin', 'methylprednisolone'),
#  ('methylprednisolone', 'methylprednisolone'),
#  ('troleandomycin', 'ketoconazole'),
#  ('troleandomycin', 'methylprednisolone'),
#  ('ketoconazole', 'methylprednisolone'),
#  ('digoxin', 'metoclopramide'),
#  ('digoxin', 'acetaminophen'),
#  ('digoxin', 'tetracycline'),
#  ('digoxin', 'levodopa'),
#  ('digoxin', 'ethanol'),
#  ('digoxin', 'cyclosporine'),
#  ('metoclopramide', 'acetaminophen'),
#  ('metoclopramide', 'tetracycline'),
#  ('metoclopramide', 'levodopa'),
#  ('metoclopramide', 'ethanol'),
#  ('metoclopramide', 'cyclosporine'),
#  ('acetaminophen', 'tetracycline'),
#  ('acetaminophen', 'levodopa'),
#  ('acetaminophen', 'ethanol'),
#  ('acetaminophen', 'cyclosporine'),
#  ('tetracycline', 'levodopa'),
#  ('tetracycline', 'ethanol'),
#  ('tetracycline', 'cyclosporine'),
#  ('levodopa', 'ethanol'),
#  ('levodopa', 'cyclosporine'),
#  ('ethanol', 'cyclosporine'),
#  ('metaraminol', 'halothane'),
#  ('Methscopolamine', 'phenelzine'),
#  ('Methscopolamine', 'linezolid'),
#  ('Methscopolamine', 'tranylcypromine'),
#  ('Methscopolamine', 'isocarboxazid'),
#  ('Methscopolamine', 'selegiline'),
#  ('Methscopolamine', 'furazolidone'),
#  ('Methscopolamine', 'quinidine'),
#  ('Methscopolamine', 'amantadine'),
#  ('Methscopolamine', 'diphenhydramine'),
#  ('Methscopolamine', 'potassium chloride'),
#  ('Methscopolamine', 'kaolin'),
#  ('Methscopolamine', 'chlorpromazine'),
#  ('Methscopolamine', 'promethazine'),
#  ('phenelzine', 'linezolid'),
#  ('phenelzine', 'tranylcypromine'),
#  ('phenelzine', 'isocarboxazid'),
#  ('phenelzine', 'selegiline'),
#  ('phenelzine', 'furazolidone'),
#  ('phenelzine', 'quinidine'),
#  ('phenelzine', 'amantadine'),
#  ('phenelzine', 'diphenhydramine'),
#  ('phenelzine', 'potassium chloride'),
#  ('phenelzine', 'kaolin'),
#  ('phenelzine', 'chlorpromazine'),
#  ('phenelzine', 'promethazine'),
#  ('linezolid', 'tranylcypromine'),
#  ('linezolid', 'isocarboxazid'),
#  ('linezolid', 'selegiline'),
#  ('linezolid', 'furazolidone'),
#  ('linezolid', 'quinidine'),
#  ('linezolid', 'amantadine'),
#  ('linezolid', 'diphenhydramine'),
#  ('linezolid', 'potassium chloride'),
#  ('linezolid', 'kaolin'),
#  ('linezolid', 'chlorpromazine'),
#  ('linezolid', 'promethazine'),
#  ('tranylcypromine', 'isocarboxazid'),
#  ('tranylcypromine', 'selegiline'),
#  ('tranylcypromine', 'furazolidone'),
#  ('tranylcypromine', 'quinidine'),
#  ('tranylcypromine', 'amantadine'),
#  ('tranylcypromine', 'diphenhydramine'),
#  ('tranylcypromine', 'potassium chloride'),
#  ('tranylcypromine', 'kaolin'),
#  ('tranylcypromine', 'chlorpromazine'),
#  ('tranylcypromine', 'promethazine'),
#  ('isocarboxazid', 'selegiline'),
#  ('isocarboxazid', 'furazolidone'),
#  ('isocarboxazid', 'quinidine'),
#  ('isocarboxazid', 'amantadine'),
#  ('isocarboxazid', 'diphenhydramine'),
#  ('isocarboxazid', 'potassium chloride'),
#  ('isocarboxazid', 'kaolin'),
#  ('isocarboxazid', 'chlorpromazine'),
#  ('isocarboxazid', 'promethazine'),
#  ('selegiline', 'furazolidone'),
#  ('selegiline', 'quinidine'),
#  ('selegiline', 'amantadine'),
#  ('selegiline', 'diphenhydramine'),
#  ('selegiline', 'potassium chloride'),
#  ('selegiline', 'kaolin'),
#  ('selegiline', 'chlorpromazine'),
#  ('selegiline', 'promethazine'),
#  ('furazolidone', 'quinidine'),
#  ('furazolidone', 'amantadine'),
#  ('furazolidone', 'diphenhydramine'),
#  ('furazolidone', 'potassium chloride'),
#  ('furazolidone', 'kaolin'),
#  ('furazolidone', 'chlorpromazine'),
#  ('furazolidone', 'promethazine'),
#  ('quinidine', 'amantadine'),
#  ('quinidine', 'diphenhydramine'),
#  ('quinidine', 'potassium chloride'),
#  ('quinidine', 'kaolin'),
#  ('quinidine', 'chlorpromazine'),
#  ('quinidine', 'promethazine'),
#  ('amantadine', 'diphenhydramine'),
#  ('amantadine', 'potassium chloride'),
#  ('amantadine', 'kaolin'),
#  ('amantadine', 'chlorpromazine'),
#  ('amantadine', 'promethazine'),
#  ('diphenhydramine', 'potassium chloride'),
#  ('diphenhydramine', 'kaolin'),
#  ('diphenhydramine', 'chlorpromazine'),
#  ('diphenhydramine', 'promethazine'),
#  ('potassium chloride', 'kaolin'),
#  ...]

# %%
def find_safe_alternative_pair(drug1, drug2, test_df, drug_alternatives):
    """Return alternative pair or note if no valid alternative found."""
    result = predict_interaction_from_df(drug1, drug2, test_df)

    if result != "Interaction":
        return {
            "original_drug1": drug1,
            "original_drug2": drug2,
            "replacement_drug1": drug1,
            "replacement_drug2": drug2,
            "status": "No Interaction"
        }

    # Get alternatives
    alternatives1 = drug_alternatives[drug_alternatives['drug'].str.lower() == drug1.lower()]
    alternatives2 = drug_alternatives[drug_alternatives['drug'].str.lower() == drug2.lower()]

    alt_drugs1 = alternatives1[['alternative_1', 'alternative_2', 'alternative_3']].values.flatten() if not alternatives1.empty else []
    alt_drugs2 = alternatives2[['alternative_1', 'alternative_2', 'alternative_3']].values.flatten() if not alternatives2.empty else []

    # Try replacing drug1 only
    for alt1 in alt_drugs1:
        alt_result = predict_interaction_from_df(alt1, drug2, test_df)
        if "No Interaction" in alt_result:
            return {
                "original_drug1": drug1,
                "original_drug2": drug2,
                "replacement_drug1": alt1,
                "replacement_drug2": drug2,
                "status": "Replaced drug1"
            }

    # Try replacing drug2 only
    for alt2 in alt_drugs2:
        alt_result = predict_interaction_from_df(drug1, alt2, test_df)
        if "No Interaction" in alt_result:
            return {
                "original_drug1": drug1,
                "original_drug2": drug2,
                "replacement_drug1": drug1,
                "replacement_drug2": alt2,
                "status": "Replaced drug2"
            }

    # Try replacing both
    for alt1 in alt_drugs1:
        for alt2 in alt_drugs2:
            alt_result = predict_interaction_from_df(alt1, alt2, test_df)
            if "No Interaction" in alt_result:
                return {
                    "original_drug1": drug1,
                    "original_drug2": drug2,
                    "replacement_drug1": alt1,
                    "replacement_drug2": alt2,
                    "status": "Replaced both"
                }

    return {
        "original_drug1": drug1,
        "original_drug2": drug2,
        "replacement_drug1": None,
        "replacement_drug2": None,
        "status": "No valid alternative"
    }

# %%
def process_all_interactions(interaction_pairs, test_df, drug_alternatives):
    results = []

    for drug1, drug2 in interaction_pairs:
        result = find_safe_alternative_pair(drug1, drug2, test_df, drug_alternatives)
        results.append(result)

    return pd.DataFrame(results)

# %%
## Size of interaction_pairs 
len(interaction_pairs)
# Out:
# 1969

# %%
results_df = process_all_interactions(interaction_pairs, test_df, drug_alternatives)
results_df
# Out:
#      original_drug1      original_drug2 replacement_drug1 replacement_drug2  \
# 0      Ketoconazole         tolterodine              None              None
# 1      ketoconazole        itraconazole      ketoconazole      itraconazole
# 2      ketoconazole          miconazole      ketoconazole        miconazole
# 3      ketoconazole        erythromycin      ketoconazole      erythromycin
# 4      ketoconazole      clarithromycin      ketoconazole    clarithromycin
# ...             ...                 ...               ...               ...
# 1964      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1965      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1966      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1967      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1968   ketoconazole  mometasone furoate      ketoconazole        Mometasone
#
#                     status
# 0     No valid alternative
# 1           No Interaction
# 2           No Interaction
# 3           No Interaction
# 4           No Interaction
# ...                    ...
# 1964        No Interaction
# 1965        No Interaction
# 1966        No Interaction
# 1967        No Interaction
# 1968        Replaced drug2
#
# [1969 rows x 5 columns]

# %%
## Check the number of statuses
status_counts = results_df['status'].value_counts()
status_counts
# Out:
# status
# No Interaction          1786
# No valid alternative      79
# Replaced drug1            47
# Replaced drug2            47
# Replaced both             10
# Name: count, dtype: int64

# %% [markdown]
# ## Evaluating Replacements

# %%
def evaluate_replacements(results_df, test_df):
    # Filter out rows with no alternative
    valid_df = results_df[results_df['status'] != "No valid alternative"].copy()

    # Add predicted label column
    predictions = []
    true_labels = []

    for _, row in valid_df.iterrows():
        d1, d2 = row['replacement_drug1'], row['replacement_drug2']
        
        # # Get model prediction
        predictions.append("No Interaction")

        # Get ground truth label from test_df
        match = test_df[
            ((test_df['Drug1'].str.lower() == d1.lower()) & (test_df['Drug2'].str.lower() == d2.lower())) |
            ((test_df['Drug1'].str.lower() == d2.lower()) & (test_df['Drug2'].str.lower() == d1.lower()))
        ]

        if not match.empty:
            true_label = match.iloc[0]['Interaction']
            true_label = "Interaction" if true_label == "true" else "No Interaction"

        else:
            true_label = "No Interaction"

        true_labels.append(true_label)

    valid_df["predicted_label"] = predictions
    valid_df["true_label"] = true_labels
    valid_df["correct"] = valid_df["predicted_label"] == valid_df["true_label"]

    # Compute accuracy
    accuracy = accuracy_score(valid_df["true_label"], valid_df["predicted_label"])
    print(f"Evaluation Accuracy (on valid replacements): {accuracy:.4f}")

    return valid_df

evaluated_df = evaluate_replacements(results_df, test_df)
evaluated_df[["original_drug1", "original_drug2", "replacement_drug1", "replacement_drug2", "status", "true_label", "predicted_label", "correct"]]
# Out:
# Evaluation Accuracy (on valid replacements): 0.9603
#      original_drug1      original_drug2 replacement_drug1 replacement_drug2  \
# 1      ketoconazole        itraconazole      ketoconazole      itraconazole
# 2      ketoconazole          miconazole      ketoconazole        miconazole
# 3      ketoconazole        erythromycin      ketoconazole      erythromycin
# 4      ketoconazole      clarithromycin      ketoconazole    clarithromycin
# 5      ketoconazole        cyclosporine      ketoconazole      cyclosporine
# ...             ...                 ...               ...               ...
# 1964      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1965      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1966      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1967      ezetimibe           ezetimibe         ezetimibe         ezetimibe
# 1968   ketoconazole  mometasone furoate      ketoconazole        Mometasone
#
#               status      true_label predicted_label  correct
# 1     No Interaction  No Interaction  No Interaction     True
# 2     No Interaction  No Interaction  No Interaction     True
# 3     No Interaction  No Interaction  No Interaction     True
# 4     No Interaction  No Interaction  No Interaction     True
# 5     No Interaction  No Interaction  No Interaction     True
# ...              ...             ...             ...      ...
# 1964  No Interaction  No Interaction  No Interaction     True
# 1965  No Interaction  No Interaction  No Interaction     True
# 1966  No Interaction  No Interaction  No Interaction     True
# 1967  No Interaction  No Interaction  No Interaction     True
# 1968  Replaced drug2  No Interaction  No Interaction     True
#
# [1890 rows x 8 columns]

# %% [markdown]
# ## **Conclusion**

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import pandas as pd

# Convert string labels to integers (if needed)
y_stacking = np.where(y_stacking == 'true', 1, 0)
y_stacking_test = np.where(y_stacking_test == 'true', 1, 0)

# Initialize different stacking models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

for name, model in models.items():
    print(f"\nTraining {name}...")
    model.fit(X_stacking, y_stacking)
    
    # Predictions on training data
    y_pred = model.predict(X_stacking)
    print(f"{name} Stacking Model Accuracy:", accuracy_score(y_stacking, y_pred))
    print(classification_report(y_stacking, y_pred))
    
    # Make final predictions on test data
    stacking_predictions = model.predict(X_stacking_test)
    
    # Evaluate the model performance
    print("Classification Report:")
    print(classification_report(y_stacking_test, stacking_predictions))
    print("Accuracy:", accuracy_score(y_stacking_test, stacking_predictions))
# Out:
# Training Logistic Regression...
# Logistic Regression Stacking Model Accuracy: 0.9770437535981578
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     23771
#            1       0.93      0.91      0.92      4021
#
#     accuracy                           0.98     27792
#    macro avg       0.96      0.95      0.95     27792
# weighted avg       0.98      0.98      0.98     27792
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4737
#            1       0.86      0.75      0.80       979
#
#     accuracy                           0.94      5716
#    macro avg       0.90      0.86      0.88      5716
# weighted avg       0.93      0.94      0.94      5716
#
# Accuracy: 0.9368439468159552
#
# Training Random Forest...
# Random Forest Stacking Model Accuracy: 0.9838442717328728
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     23771
#            1       0.95      0.94      0.94      4021
#
#     accuracy                           0.98     27792
#    macro avg       0.97      0.97      0.97     27792
# weighted avg       0.98      0.98      0.98     27792
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4737
#            1       0.83      0.77      0.80       979
#
#     accuracy                           0.93      5716
#    macro avg       0.89      0.87      0.88      5716
# weighted avg       0.93      0.93      0.93      5716
#
# Accuracy: 0.9326452064380686
#
# Training Gradient Boosting...
# Gradient Boosting Stacking Model Accuracy: 0.9777993667242372
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     23771
#            1       0.93      0.92      0.92      4021
#
#     accuracy                           0.98     27792
#    macro avg       0.96      0.95      0.95     27792
# weighted avg       0.98      0.98      0.98     27792
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4737
#            1       0.85      0.77      0.81       979
#
#     accuracy                           0.94      5716
#    macro avg       0.90      0.87      0.88      5716
# weighted avg       0.94      0.94      0.94      5716
#
# Accuracy: 0.9370188943317005
#
# Training XGBoost...
# XGBoost Stacking Model Accuracy: 0.977367587795049
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     23771
#            1       0.92      0.93      0.92      4021
#
#     accuracy                           0.98     27792
#    macro avg       0.95      0.96      0.95     27792
# weighted avg       0.98      0.98      0.98     27792
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4737
#            1       0.84      0.78      0.81       979
#
#     accuracy                           0.94      5716
#    macro avg       0.90      0.88      0.89      5716
# weighted avg       0.94      0.94      0.94      5716
#
# Accuracy: 0.9371938418474458

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
nn_model = Sequential([
    Dense(128, activation='relu', input_shape=(X_stacking.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

print("\nTraining Neural Network...")
nn_model.fit(X_stacking, y_stacking, epochs=20, batch_size=16, verbose=1, validation_split=0.1)

# Make predictions
nn_predictions = (nn_model.predict(X_stacking_test) > 0.5).astype(int)

# Evaluate the neural network
print("Neural Network Classification Report:")
print(classification_report(y_stacking_test, nn_predictions))
print("Neural Network Accuracy:", accuracy_score(y_stacking_test, nn_predictions))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Neural Network...
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740425367.561418      72 service.cc:145] XLA service 0x7e8f7400b7d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740425367.561462      72 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1740425367.561468      72 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  116/1564 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8039 - loss: 0.4060
# I0000 00:00:1740425370.681268      72 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9508 - loss: 0.1180 - val_accuracy: 0.9781 - val_loss: 0.0549
# Epoch 2/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9766 - loss: 0.0575 - val_accuracy: 0.9784 - val_loss: 0.0538
# Epoch 3/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9758 - loss: 0.0549 - val_accuracy: 0.9784 - val_loss: 0.0499
# Epoch 4/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9770 - loss: 0.0500 - val_accuracy: 0.9781 - val_loss: 0.0497
# Epoch 5/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9759 - loss: 0.0547 - val_accuracy: 0.9784 - val_loss: 0.0508
# Epoch 6/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9756 - loss: 0.0536 - val_accuracy: 0.9781 - val_loss: 0.0498
# Epoch 7/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9779 - loss: 0.0486 - val_accuracy: 0.9784 - val_loss: 0.0502
# Epoch 8/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9768 - loss: 0.0492 - val_accuracy: 0.9781 - val_loss: 0.0502
# Epoch 9/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9782 - loss: 0.0481 - val_accuracy: 0.9784 - val_loss: 0.0492
# Epoch 10/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9777 - loss: 0.0498 - val_accuracy: 0.9781 - val_loss: 0.0493
# Epoch 11/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9758 - loss: 0.0513 - val_accuracy: 0.9784 - val_loss: 0.0491
# Epoch 12/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9784 - loss: 0.0499 - val_accuracy: 0.9784 - val_loss: 0.0483
# Epoch 13/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9750 - loss: 0.0497 - val_accuracy: 0.9766 - val_loss: 0.0491
# Epoch 14/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9787 - loss: 0.0480 - val_accuracy: 0.9784 - val_loss: 0.0502
# Epoch 15/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9760 - loss: 0.0475 - val_accuracy: 0.9784 - val_loss: 0.0481
# Epoch 16/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9771 - loss: 0.0468 - val_accuracy: 0.9784 - val_loss: 0.0487
# Epoch 17/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9784 - loss: 0.0468 - val_accuracy: 0.9791 - val_loss: 0.0526
# Epoch 18/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9765 - loss: 0.0498 - val_accuracy: 0.9781 - val_loss: 0.0488
# Epoch 19/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9764 - loss: 0.0494 - val_accuracy: 0.9791 - val_loss: 0.0484
# Epoch 20/20
# 1564/1564 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9782 - loss: 0.0494 - val_accuracy: 0.9781 - val_loss: 0.0485
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4737
#            1       0.83      0.80      0.81       979
#
#     accuracy                           0.94      5716
#    macro avg       0.89      0.88      0.89      5716
# weighted avg       0.94      0.94      0.94      5716
#
# Neural Network Accuracy: 0.9371938418474458
